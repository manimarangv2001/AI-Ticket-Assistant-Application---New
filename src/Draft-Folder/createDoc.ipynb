# %%
import requests
import os
from langchain.docstore.document import Document
from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI 
from langchain_core.prompts import PromptTemplate
from langchain_chroma import Chroma

# %%
embedding_function = AzureOpenAIEmbeddings(model="Text-embedding")

# %%
model = AzureChatOpenAI(
    openai_api_version=os.environ["AZURE_OPENAI_API_VERSION"],
    azure_deployment=os.environ["AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"],
)

# %%
user = 'admin'
pwd = 'wr^zd%PWRC12'

headers = {"Content-Type":"application/json","Accept":"application/json"}

def get_catalog_item_collection():
    url = 'https://dev199703.service-now.com/api/now/table/sc_cat_item?sysparm_query=sc_catalogsLIKEe0d08b13c3330100c8b837659bba8fb4%5Eactive%3Dtrue'
    response = requests.get(url, auth=(user, pwd), headers=headers )
    if response.status_code != 200: 
        data = {'result':{'sys_id': "", 'sys_name': "",'short_description':"",'description':""}, 'Status': response.status_code, 'Headers': response.headers, 'Error Response':response.json()}
    data = response.json()
    return data

# %%
def get_catalog_item(sys_id):
    url = f'https://dev199703.service-now.com/api/sn_sc/servicecatalog/items/{sys_id}'
    response = requests.get(url, auth=(user, pwd), headers=headers )
    if response.status_code != 200: 
        print('Status:', response.status_code, 'Headers:', response.headers, 'Error Response:',response.json())
    data = response.json()
    return data

# %%
def get_table_values(reference):
    url = f'https://dev199703.service-now.com/api/now/table/{reference}'
    response = requests.get(url, auth=(user, pwd), headers=headers )
    if response.status_code != 200: 
        print('Status:', response.status_code, 'Headers:', response.headers, 'Error Response:',response.json())
        exit()
    data = response.json()
    return data

# %%
def descriptionMaker(data):

    template = """{data}
    
    using this data provide a proper description for this catalog item.
    In the Json data, variables has choices mention all of it in description (Mandatory)
    
    Example:

    Catalog Item Name: Software Services

    Description:
    The Software Services catalog item allows users to request various software-related services. This includes the following actions:

    Software Installation: Users can request the installation of software such as Adobe Acrobat DC Pro or Python.
    Software Uninstallation: Users can request the removal of existing software.
    OS Update: Users can request updates to their operating systems.
    This item is available on the desktop and is designed to streamline the process of managing software needs efficiently.

    Variables (Fields):
    Requested for: The user for whom the request is made (mandatory).
    Contact Number: The contact number of the requester.
    Location: The location of the requester.
    Project Name: The department or project name associated with the request.
    Business Service: The specific service being requested (Software Installation, Software Uninstallation, OS Upgrade).
    Software Name: The specified software being requested (Adobe Acrobat DC Pro, Python).
    Add Software: Option to add software.
    Request Type: The type of request, e.g., Software Installation - Freeware.
    Duration: The expected duration for the service.
    Correct Host Name: Selection of the correct host name where the service will be applied.
    UI Policy Description
    UI Policies define the visibility and behavior of certain fields based on the selected Business Service.

    UI Policy for Software Installation:

    Condition:
    This policy is triggered if the Business Service field is set to "Software Installation".
    Actions:
    When this condition is met, several fields related to the software installation process are made visible to the user.
    Fields affected by this policy include the Software Name, Request Type, Duration, and Add Software options.
    UI Policy for Software Uninstallation:

    Condition:
    This policy is triggered if the Business Service field is set to "Software Uninstallation".
    Actions:
    When this condition is met, fields related to the software uninstallation process are made visible.
    Specifically, the Software Name field will be visible, allowing users to select which software they wish to uninstall.
    These UI policies ensure that users only see and interact with fields relevant to the specific service they are requesting, enhancing the user experience by simplifying the form and reducing unnecessary complexity.

    
    """
    
    prompt_template = PromptTemplate(template=template, input_variables=["data"])
    chain = prompt_template | model
    response = chain.invoke({"data": data})
    return response

# %%
catalog_item_collection = get_catalog_item_collection()

# %%
def set_reference_value(variable):
    if(variable['type'] == 8 and variable['dynamic_value_field'] == ''):
        reference = variable['reference']
        table_content = get_table_values(reference=reference)
        # print(table_content)
        names_in_table = []
        for content in table_content['result']:
            if('u_name' in content):
                names_in_table.append(content['u_name'])
        variable['value'] = names_in_table
        #print(variable)
        return variable
    else:
        return variable

def arrange_response(catalog_item_json):
    variables = catalog_item_json['result']['variables']
    new_variables = []
    for variable in variables:
        if 'children' in variable:
            children_List = []
            for children in variable['children']:
                children_List.append(set_reference_value(children))
            variable['children'] = children_List
            new_variables.append(variable)
        else:
            new_variables.append(set_reference_value(variable))

    catalog_item_json['result']['variables'] = new_variables
    return catalog_item_json

# %%
elemenate_items = [
    'Password Reset',
    'Service Fulfillment Steps - Custom approval step',
    'Record Producer Builder',
    'Report Performance Problem',
    'Report Outage',
    'Service Fulfillment Steps - Base step',
    'Service Fulfillment Steps - Task step',
    'Catalog Variable Creation',
    'Catalog UI Policy',
    'Catalog Item Builder',
    'Replace printer toner',
    'Password Reset Enrollment'
    ]

def createDocuments():
    docs=[]
    for catalog_item in catalog_item_collection['result']:
        if(catalog_item['sys_name'] in elemenate_items):
            continue
        print(catalog_item)
        metadata = {"sys_id":catalog_item['sys_id'], "sys_name":catalog_item['sys_name']}
        catalog_item_json = arrange_response(get_catalog_item(catalog_item['sys_id']))
        description = descriptionMaker(catalog_item_json)
        docs.append(Document(page_content=description.content, metadata=metadata))
        print(description.content)
    return docs

# %%
# from langchain_pinecone import PineconeVectorStore

# docsearch = PineconeVectorStore.from_documents(docs, embeddings, index_name=index_name)

# %%
query = "I need to install python"

# %%
path = './chroma_db'
isdir = os.path.isdir(path)
if(not isdir):
    db2 = Chroma.from_documents(documents=createDocuments(), embedding=embedding_function, persist_directory=path)
# Out:
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2022-11-21 04:46:33', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'ryan.hale', 'price': '0', 'sys_created_on': '2014-01-30 16:04:26', 'recurring_frequency': '', 'sys_name': 'Request Developer Project Equipment', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'admin', 'group': '', 'hide_sp': 'false', 'order': '0', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': {'link': 'https://dev199703.service-now.com/api/now/table/sc_cat_item_delivery_plan/523da512c611228900811a37c97c2014', 'value': '523da512c611228900811a37c97c2014'}, 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '', 'ignore_price': 'false', 'sys_update_name': 'sc_cat_item_guide_25110912372211003e7d40ed9dbe5dd6', 'meta': '', 'omit_price': 'false', 'name': 'Request Developer Project Equipment', 'flow_designer_flow': '', 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_guide_view.do?v=1&sysparm_initial=true&sysparm_guide=25110912372211003e7d40ed9dbe5dd6&sysparm_preview=true", "summary");', 'template': '', 'short_description': 'Request hardware and software to support a\n\t\t\tdevelopment project\n\t\t', 'access_type': '', 'fulfillment_automation_level': '', 'roles': '', 'icon': '', 'description': '<p>Request hardware and software to support a development project</p>', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item_guide', 'sys_id': '25110912372211003e7d40ed9dbe5dd6', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': 'use_desktop_picture', 'sys_scope': {'link': 'https://dev199703.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': '', 'no_delivery_time_v2': 'false', 'cost': '0', 'no_quantity_v2': 'false', 'sys_mod_count': '6', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '', 'sys_package': {'link': 'https://dev199703.service-now.com/api/now/table/sys_package/5c48b34ce492021008dda4ccc4008068', 'value': '5c48b34ce492021008dda4ccc4008068'}, 'display_price_property': 'non_zero', 'taxonomy_topic': {'link': 'https://dev199703.service-now.com/api/now/table/topic/988497a7c3053010069aec4b7d40ddea', 'value': '988497a7c3053010069aec4b7d40ddea'}, 'delivery_plan_script': '', 'location': '', 'category': '', 'no_save_as_draft': 'false'}
# Catalog Item Name: Request Developer Project Equipment
#
# Description:
# The "Request Developer Project Equipment" catalog item allows users to request both hardware and software necessary to support a development project. This item is designed to streamline the process of obtaining the necessary equipment and software for development purposes efficiently and effectively.
#
# This catalog item includes the following actions:
#
# 1. Hardware Request: Users can request the necessary hardware for their development projects.
# 2. Software Request: Users can request the required software to support their development activities.
#
# Availability:
# - This item is available on desktop platforms.
#
# Variables (Fields):
# 1. **Are you developing for Android or iOS?** (Select Box)
#    - Choices:
#      - Android
#      - iOS
#      - Both
#
# 2. **What software do you require?** (List Collector)
#    - Allows users to select multiple software items from the catalog.
#
# This catalog item includes options to specify the development platform (Android, iOS, or Both) and the specific software required for the project. By providing these details, users can ensure they receive the appropriate hardware and software to meet their development needs. The item is visible as a standalone option in the Service Catalog and includes features to show the delivery time and add items to a wishlist.
#
# UI Policy and Client Script:
# There are no UI policies or client scripts defined for this catalog item, ensuring a straightforward and user-friendly experience.
#
# By using this catalog item, developers can efficiently request the necessary tools to support their projects, ensuring they have the right resources to succeed.
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2024-07-09 12:23:36', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'admin', 'price': '0', 'sys_created_on': '2024-07-01 11:27:08', 'recurring_frequency': '', 'sys_name': 'Report IT Incidents', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'admin', 'group': '', 'hide_sp': 'false', 'order': '0', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': '', 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '199', 'ignore_price': 'true', 'sys_update_name': 'sc_cat_item_383b0ff693cf821005f472ba2bba1057', 'meta': '', 'omit_price': 'false', 'name': 'Report IT Incidents', 'flow_designer_flow': {'link': 'https://dev199703.service-now.com/api/now/table/sys_hub_flow/90a2a08b9387c21005f472ba2bba109f', 'value': '90a2a08b9387c21005f472ba2bba109f'}, 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_view.do?v=1&sysparm_id=383b0ff693cf821005f472ba2bba1057&sysparm_preview=true", "summary");', 'template': '', 'short_description': 'Get support with STG issues that you are facing', 'access_type': 'restricted', 'fulfillment_automation_level': 'unspecified', 'roles': '', 'icon': '', 'description': '<p>In this form you can raise a Incident related to STG Issue.</p>', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item', 'sys_id': '383b0ff693cf821005f472ba2bba1057', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': 'use_desktop_picture', 'sys_scope': {'link': 'https://dev199703.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': {'link': 'https://dev199703.service-now.com/api/now/table/sys_user/6816f79cc0a8016401c5a33be04be441', 'value': '6816f79cc0a8016401c5a33be04be441'}, 'no_delivery_time_v2': 'false', 'cost': '0', 'no_quantity_v2': 'false', 'sys_mod_count': '75', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '', 'sys_package': {'link': 'https://dev199703.service-now.com/api/now/table/sys_package/global', 'value': 'global'}, 'display_price_property': 'non_zero', 'taxonomy_topic': '', 'delivery_plan_script': '', 'location': '', 'category': '', 'no_save_as_draft': 'false'}
# ### Catalog Item Name: Report IT Incidents
#
# #### Description:
# The "Report IT Incidents" catalog item allows users to report various IT-related issues, ensuring they receive timely support and resolution. Users can provide detailed information about the incident they are facing, including the requested service, category, and specific details about the issue.
#
# #### Variables (Fields):
#
# 1. **Requested for:** The user for whom the request is made. (Mandatory)
# 2. **Location:** The location of the requester. (Mandatory)
# 3. **Contact Number:** The contact number of the requester. (Mandatory)
# 4. **Project Name:** The department or project name associated with the request. (Mandatory)
# 5. **Building:** The building information if applicable.
# 6. **Service:** The specific service being requested. (Mandatory)
#    - **Choices:**
#      - Alerts Monitoring
#      - Application Services
#      - AskGenie Administration
#      - DC Ops Services
#      - End user computing (Deskside) services
#      - Network Services
#      - Video Conference
#      - Voice Services
# 7. **Category:** The category of the incident. (Mandatory)
#    - **Choices:**
#      - Allowances
#      - Application Issue
#      - Application or Database Alerts
#      - ART
#      - Network alerts
#      - Server or Cloud Alerts
# 8. **Child Category 1:** A more specific category of the incident. (Mandatory)
#    - **Choices:**
#      - Application
#      - Availability
#      - CPPM
#      - CPU Utilization
#      - Data
#      - Database
#      - Diskspace Utilization
#      - Down
#      - Error
#      - Firewall
#      - ION
#      - Memory Utilization
#      - Performance
#      - Physical server - Linux
#      - Physical server - Windows
#      - Router
#      - Service Down
#      - Storage
#      - Switch
#      - Virtual Server - Linux
#      - Virtual Server - Windows
#      - Wireless controller
# 9. **Short Description:** A brief summary of the incident. (Mandatory)
# 10. **Detailed Description:** A detailed description of the incident. (Mandatory)
#
# #### UI Policy Description:
#
# **UI Policies** define the visibility and behavior of certain fields based on specific conditions. The following UI policies are applied to this catalog item:
#
# 1. **UI Policy for Adding Software:**
#    - **Condition:** This policy is triggered if the "Add Software" option is clicked.
#    - **Actions:** When this condition is met, another container is added to the form.
#    - **OnLoad:** True
#    - **Reverse:** True
#
# 2. **UI Policy for Business Service:**
#    - **Condition:** This policy is triggered if the business service is related to software installation.
#    - **Actions:** When this condition is met, relevant fields related to the software installation process are made visible.
#    - **OnLoad:** True
#    - **Reverse:** True
#
# These UI policies ensure that users only see and interact with fields relevant to the specific service they are requesting, enhancing the user experience by simplifying the form and reducing unnecessary complexity.
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2018-04-09 20:26:31', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'admin', 'price': '0', 'sys_created_on': '2014-04-11 23:40:12', 'recurring_frequency': '', 'sys_name': 'Change Password', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'admin', 'group': '', 'hide_sp': 'false', 'order': '0', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': {'link': 'https://dev199703.service-now.com/api/now/table/sc_cat_item_delivery_plan/523da512c611228900811a37c97c2014', 'value': '523da512c611228900811a37c97c2014'}, 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '', 'ignore_price': 'true', 'sys_update_name': 'sc_cat_item_content_3c72dc91eb00210045e1a5115206fec7', 'meta': '', 'omit_price': 'false', 'name': 'Change Password', 'flow_designer_flow': '', 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_view.do?v=1&sysparm_id=3c72dc91eb00210045e1a5115206fec7&sysparm_preview=true", "summary");', 'template': '', 'short_description': '', 'access_type': 'restricted', 'fulfillment_automation_level': 'unspecified', 'roles': '', 'icon': '', 'description': '', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item_content', 'sys_id': '3c72dc91eb00210045e1a5115206fec7', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': 'use_desktop_picture', 'sys_scope': {'link': 'https://dev199703.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': '', 'no_delivery_time_v2': 'false', 'cost': '0', 'no_quantity_v2': 'false', 'sys_mod_count': '9', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '', 'sys_package': {'link': 'https://dev199703.service-now.com/api/now/table/sys_package/ef6a330ce4d2021008dda4ccc40080f5', 'value': 'ef6a330ce4d2021008dda4ccc40080f5'}, 'display_price_property': 'non_zero', 'taxonomy_topic': '', 'delivery_plan_script': '', 'location': '', 'category': {'link': 'https://dev199703.service-now.com/api/now/table/sc_category/e15706fc0a0a0aa7007fc21e1ab70c2f', 'value': 'e15706fc0a0a0aa7007fc21e1ab70c2f'}, 'no_save_as_draft': 'false'}
# Catalog Item Name: Change Password
#
# Description:
# The Change Password catalog item allows users to conveniently update their current passwords. This service is essential for maintaining the security and privacy of user accounts.
#
# This item is available on the desktop, ensuring that users can access it easily when needed. The Change Password item is designed to be simple and efficient, providing a straightforward way to enhance account security.
#
# Variables (Fields):
# There are no additional fields (variables) specified for this catalog item, ensuring a streamlined process for users to change their passwords without any additional complexity.
#
# UI Policy Description:
# There are no specific UI policies associated with this catalog item, ensuring a consistent and straightforward user experience without any conditional field visibility or behavior changes.
#
# Client Script Description:
# There are no client scripts (onChange, onSubmit, onLoad) associated with this catalog item, ensuring that the process remains simple and free from additional scripted behaviors.
#
# Additional Information:
# - Availability: This service is available on the desktop.
# - Mandatory Attachment: No attachments are required to use this service.
# - Request Method: Not specified.
# - Content Type: External, indicating that the process might involve external systems or redirects.
# - URL: Users can access the Change Password service through the following URL: [/pwd_change.do](https://example.com/$pwd_change.do).
#
# This catalog item is part of the "Can We Help You?" category in the Service Catalog, making it easy for users to find and use this essential security feature.
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2024-07-09 12:24:37', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'admin', 'price': '0', 'sys_created_on': '2024-07-01 07:15:59', 'recurring_frequency': '', 'sys_name': 'Software Services', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'admin', 'group': '', 'hide_sp': 'false', 'order': '0', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': '', 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '164', 'ignore_price': 'true', 'sys_update_name': 'sc_cat_item_4391de3e938b821005f472ba2bba1096', 'meta': '', 'omit_price': 'false', 'name': 'Software Services', 'flow_designer_flow': {'link': 'https://dev199703.service-now.com/api/now/table/sys_hub_flow/b89f18c79387c21005f472ba2bba1052', 'value': 'b89f18c79387c21005f472ba2bba1052'}, 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_view.do?v=1&sysparm_id=4391de3e938b821005f472ba2bba1096&sysparm_preview=true", "summary");', 'template': '', 'short_description': 'Software Services', 'access_type': 'restricted', 'fulfillment_automation_level': 'unspecified', 'roles': '', 'icon': '', 'description': '<div>\r\n<ul><li>In this catalog item we can raise a ticket for\r\n<ul><li>Software installation</li><li>Software Uninstallation</li><li>OS update</li></ul>\r\n</li></ul>\r\n</div>', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item', 'sys_id': '4391de3e938b821005f472ba2bba1096', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': 'use_desktop_picture', 'sys_scope': {'link': 'https://dev199703.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': {'link': 'https://dev199703.service-now.com/api/now/table/sys_user/6816f79cc0a8016401c5a33be04be441', 'value': '6816f79cc0a8016401c5a33be04be441'}, 'no_delivery_time_v2': 'false', 'cost': '0', 'no_quantity_v2': 'false', 'sys_mod_count': '164', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '', 'sys_package': {'link': 'https://dev199703.service-now.com/api/now/table/sys_package/global', 'value': 'global'}, 'display_price_property': 'non_zero', 'taxonomy_topic': '', 'delivery_plan_script': '', 'location': '', 'category': '', 'no_save_as_draft': 'false'}
# ```markdown
# Catalog Item Name: Software Services
#
# Description:
# The Software Services catalog item allows users to request various software-related services. This includes the following actions:
#
# - **Software Installation**: Users can request the installation of software such as Adobe Acrobat DC Pro or Python.
# - **Software Uninstallation**: Users can request the removal of existing software.
# - **OS Update**: Users can request updates to their operating systems.
#
# This item is available on the desktop and is designed to streamline the process of managing software needs efficiently.
#
# Variables (Fields):
# 1. **Requested for**: The user for whom the request is made (mandatory).
# 2. **Contact Number**: The contact number of the requester.
# 3. **Location**: The location of the requester.
# 4. **Project Name**: The department or project name associated with the request.
# 5. **Business Service**: The specific service being requested (Software Installation, Software Uninstallation, OS Upgrade).
# 6. **Software Name**: The specified software being requested (Adobe Acrobat DC Pro, Python).
# 7. **Add Software**: Option to add software.
# 8. **Request Type**: The type of request, e.g., Software Installation - Freeware.
# 9. **Duration**: The expected duration for the service.
# 10. **Correct Host Name**: Selection of the correct host name where the service will be applied.
#
# UI Policy Description:
# UI Policies define the visibility and behavior of certain fields based on the selected Business Service.
#
# **UI Policy for Software Installation**:
#
# - **Condition**:
#   - This policy is triggered if the Business Service field is set to "Software Installation".
# - **Actions**:
#   - When this condition is met, several fields related to the software installation process are made visible to the user.
#   - Fields affected by this policy include the Software Name, Request Type, Duration, and Add Software options.
#
# **UI Policy for Software Uninstallation**:
#
# - **Condition**:
#   - This policy is triggered if the Business Service field is set to "Software Uninstallation".
# - **Actions**:
#   - When this condition is met, fields related to the software uninstallation process are made visible.
#   - Specifically, the Software Name field will be visible, allowing users to select which software they wish to uninstall.
#
# These UI policies ensure that users only see and interact with fields relevant to the specific service they are requesting, enhancing the user experience by simplifying the form and reducing unnecessary complexity.
# ```
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2022-11-21 04:46:33', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'admin', 'price': '0', 'sys_created_on': '2015-11-22 19:18:37', 'recurring_frequency': '', 'sys_name': 'New Hire', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'ryan.hale', 'group': '', 'hide_sp': 'false', 'order': '50', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': {'link': 'https://dev199703.service-now.com/api/now/table/sc_cat_item_delivery_plan/523da512c611228900811a37c97c2014', 'value': '523da512c611228900811a37c97c2014'}, 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '', 'ignore_price': 'false', 'sys_update_name': 'sc_cat_item_guide_6690750f4f7b4200086eeed18110c761', 'meta': '', 'omit_price': 'false', 'name': 'New Hire', 'flow_designer_flow': '', 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_guide_view.do?v=1&sysparm_initial=true&sysparm_guide=6690750f4f7b4200086eeed18110c761&sysparm_preview=true", "summary");', 'template': '', 'short_description': 'New Hire Order Guide', 'access_type': '', 'fulfillment_automation_level': '', 'roles': '', 'icon': '', 'description': '<p style="font-size: 13px;"><font size="4"><span>Service Overview:</span></font></p>\n<p><font size="3">The New Hire package includes all necessary tasks to enable your new employee to be productive on day one such as, hardware provisioning, software access, and account creation. \xa0Unless otherwise noted all new employees receive the standard package detailed below. \xa0</font></p>\n<p style="font-size: 13px;"><span>\xa0</span></p>\n<p style="font-size: 13px;"><font size="4"><span>Services Include:</span></font></p>\n<ul><li><font size="3">Email account creation</font></li><li><font size="3">Lenovo Carbon x1</font></li><li><font size="3">One external monitor</font></li><li><font size="3">MS Office Suite:</font>\n<ul><li><font size="2">Outlook</font></li><li><font size="2">Word</font></li><li><font size="2">PowerPoint</font></li><li><font size="2">Excel</font></li><li><font size="2">OneNote</font></li></ul>\n</li></ul>', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item_guide', 'sys_id': '6690750f4f7b4200086eeed18110c761', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': 'use_desktop_picture', 'sys_scope': {'link': 'https://dev199703.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': '', 'no_delivery_time_v2': 'false', 'cost': '0', 'no_quantity_v2': 'false', 'sys_mod_count': '10', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '1a856a72779611105e3db2a07b5a9993', 'sys_package': {'link': 'https://dev199703.service-now.com/api/now/table/sys_package/5c48b34ce492021008dda4ccc4008068', 'value': '5c48b34ce492021008dda4ccc4008068'}, 'display_price_property': 'non_zero', 'taxonomy_topic': {'link': 'https://dev199703.service-now.com/api/now/table/topic/06d3df67c3053010069aec4b7d40dd70', 'value': '06d3df67c3053010069aec4b7d40dd70'}, 'delivery_plan_script': '', 'location': '', 'category': {'link': 'https://dev199703.service-now.com/api/now/table/sc_category/e15706fc0a0a0aa7007fc21e1ab70c2f', 'value': 'e15706fc0a0a0aa7007fc21e1ab70c2f'}, 'no_save_as_draft': 'false'}
# Catalog Item Name: New Hire Order Guide
#
# Description:
# The New Hire Order Guide catalog item is designed to streamline the onboarding process for new employees, ensuring they are equipped with the necessary tools and access to be productive from day one. The package includes tasks such as hardware provisioning, software access, and account creation. Unless specified otherwise, all new employees receive the standard package outlined below.
#
# Service Overview:
# - **Email account creation**
# - **Hardware**: Lenovo Carbon x1 and one external monitor
# - **Software**: MS Office Suite including Outlook, Word, PowerPoint, Excel, and OneNote
#
# This item is available on the desktop and is tailored to ensure a smooth and efficient onboarding process.
#
# Variables (Fields):
# 1. **Hiring Manager**: The system administrator or user responsible for the new hire (mandatory).
# 2. **What group is this person joining**: The department or group the new hire will be part of (mandatory).
# 3. **Will this be a remote employee?**: Yes/No option to indicate if the employee will be working remotely (mandatory). Choices:
#    - Yes
#    - No
# 4. **What office will they report to**: The physical office location where the new hire will report (optional).
# 5. **Will your employee need anything non-standard?**: Yes/No option to specify if the new hire requires any non-standard equipment or software (mandatory). Choices:
#    - Yes
#    - No
# 6. **What Device Type**: The type of laptop required for the new hire (optional). Choices:
#    - Developer
#    - Sales
# 7. **Mobile Device Type**: The type of mobile device required (optional). Choices:
#    - -- None --
#    - iPhone
#    - Android
#
# UI Policy Description:
# UI Policies are in place to control the visibility and behavior of certain fields based on user selections.
#
# 1. **Default Values for Developers**: This policy sets default values specifically for developers.
#
# 2. **Hide Device Type and other attributes**:
#    - **Condition**: This policy is triggered if the field "Will your employee need anything non-standard?" is set to "No".
#    - **Actions**: When the condition is met, the fields for mobile device type and laptop type are hidden from the form.
#
# These UI policies ensure a streamlined user experience by displaying only the relevant fields based on the specific needs of the new hire, thereby reducing unnecessary complexity and enhancing the efficiency of the onboarding process.
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2010-05-13 12:44:14', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'admin', 'price': '0', 'sys_created_on': '2010-05-13 12:44:14', 'recurring_frequency': '', 'sys_name': 'Company portal', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'admin', 'group': '', 'hide_sp': 'false', 'order': '0', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': {'link': 'https://dev199703.service-now.com/api/now/table/sc_cat_item_delivery_plan/523da512c611228900811a37c97c2014', 'value': '523da512c611228900811a37c97c2014'}, 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '', 'ignore_price': 'false', 'sys_update_name': 'sc_cat_item_content_91af400f0a0a3c74009c70d0e7c08977', 'meta': '', 'omit_price': 'false', 'name': 'Company portal', 'flow_designer_flow': '', 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_view.do?v=1&sysparm_id=91af400f0a0a3c74009c70d0e7c08977&sysparm_preview=true", "summary");', 'template': '', 'short_description': '', 'access_type': '', 'fulfillment_automation_level': '', 'roles': '', 'icon': '', 'description': '', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item_content', 'sys_id': '91af400f0a0a3c74009c70d0e7c08977', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': '', 'sys_scope': {'link': 'https://dev199703.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': '', 'no_delivery_time_v2': 'false', 'cost': '', 'no_quantity_v2': 'false', 'sys_mod_count': '0', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '', 'sys_package': {'link': 'https://dev199703.service-now.com/api/now/table/sys_package/5c48b34ce492021008dda4ccc4008068', 'value': '5c48b34ce492021008dda4ccc4008068'}, 'display_price_property': 'non_zero', 'taxonomy_topic': '', 'delivery_plan_script': '', 'location': '', 'category': {'link': 'https://dev199703.service-now.com/api/now/table/sc_category/91a9e0510a0a3c7401d20d86782fc9a0', 'value': '91a9e0510a0a3c7401d20d86782fc9a0'}, 'no_save_as_draft': 'false'}
# Catalog Item Name: Company Portal
#
# Description:
# The Company Portal catalog item provides users with quick access to the company’s main service portal. This portal serves as a centralized location for accessing various services, information, and resources provided by the organization.
#
# This item is available on the desktop and aims to streamline the process of navigating the company’s online services, offering a more efficient and user-friendly experience.
#
# Variables (Fields):
# Currently, there are no specific variables or fields associated with this catalog item.
#
# UI Policy Description:
# There are no specific UI policies defined for this catalog item.
#
# Client Script Description:
# There are no client scripts defined for this catalog item.
#
# Additional Information:
# - **URL**: [Company Portal](http://www.service-now.com)
# - **Category**: Quick Links
# - **Availability**: On Desktop
# - **Show Quantity**: Yes
# - **Show Wishlist**: Yes
# - **Show Delivery Time**: Yes
# - **Content Type**: External
#
# This catalog item is a part of the "Service Catalog" and falls under the "Quick Links" category, making it easily accessible for users seeking essential company resources and services.
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2010-05-13 12:45:03', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'admin', 'price': '0', 'sys_created_on': '2010-05-13 12:45:03', 'recurring_frequency': '', 'sys_name': 'Company policies', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'admin', 'group': '', 'hide_sp': 'false', 'order': '0', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': {'link': 'https://dev199703.service-now.com/api/now/table/sc_cat_item_delivery_plan/523da512c611228900811a37c97c2014', 'value': '523da512c611228900811a37c97c2014'}, 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '', 'ignore_price': 'false', 'sys_update_name': 'sc_cat_item_content_91b257180a0a3c74012fb6b78e634614', 'meta': '', 'omit_price': 'false', 'name': 'Company policies', 'flow_designer_flow': '', 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_view.do?v=1&sysparm_id=91b257180a0a3c74012fb6b78e634614&sysparm_preview=true", "summary");', 'template': '', 'short_description': '', 'access_type': '', 'fulfillment_automation_level': '', 'roles': '', 'icon': '', 'description': '', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item_content', 'sys_id': '91b257180a0a3c74012fb6b78e634614', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': '', 'sys_scope': {'link': 'https://dev199703.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': '', 'no_delivery_time_v2': 'false', 'cost': '', 'no_quantity_v2': 'false', 'sys_mod_count': '0', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '', 'sys_package': {'link': 'https://dev199703.service-now.com/api/now/table/sys_package/5c48b34ce492021008dda4ccc4008068', 'value': '5c48b34ce492021008dda4ccc4008068'}, 'display_price_property': 'non_zero', 'taxonomy_topic': '', 'delivery_plan_script': '', 'location': '', 'category': {'link': 'https://dev199703.service-now.com/api/now/table/sc_category/91a9e0510a0a3c7401d20d86782fc9a0', 'value': '91a9e0510a0a3c7401d20d86782fc9a0'}, 'no_save_as_draft': 'false'}
# Catalog Item Name: Company Policies
#
# Description:
# The Company Policies catalog item provides users with access to various company policies and guidelines. This item is designed to ensure that employees are well-informed about the rules and regulations that govern their work environment. The policies cover a broad range of topics essential for maintaining a productive and compliant workplace.
#
# This item is available on the desktop and offers a convenient way for users to view and understand the company's policies and procedures. By centralizing this information, the Company Policies catalog item helps employees stay updated and aligned with the organization's standards.
#
# Variables (Fields):
# Currently, there are no specific variables (fields) listed for this catalog item.
#
# UI Policy Description:
# There are no UI Policies defined for this catalog item.
#
# Client Script:
# There are no client scripts defined for this catalog item.
#
# Additional Information:
# - **KB Article**: The catalog item links to a knowledge base article with the sys_id `1addc9f1474321009db4b5b08b9a7120`.
# - **Category**: The item is categorized under "Quick Links".
# - **Availability**: Available on the desktop.
# - **Show Price**: No price is displayed.
# - **Show Quantity**: Quantity can be specified.
# - **Show Wishlist**: Users can add this item to their wishlist.
# - **Show Delivery Time**: Delivery time is shown.
#
# The Company Policies catalog item is an essential resource for employees, providing easy access to the company's policies and ensuring that everyone remains informed and compliant with organizational standards.
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2024-07-09 12:24:11', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'admin', 'price': '0', 'sys_created_on': '2024-07-08 14:19:18', 'recurring_frequency': '', 'sys_name': 'Restart Linux Services', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'admin', 'group': '', 'hide_sp': 'false', 'order': '0', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': {'link': 'https://dev199703.service-now.com/api/now/table/sc_cat_item_delivery_plan/523da512c611228900811a37c97c2014', 'value': '523da512c611228900811a37c97c2014'}, 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '24', 'ignore_price': 'true', 'sys_update_name': 'sc_cat_item_9ca5f701931b021005f472ba2bba108f', 'meta': '', 'omit_price': 'false', 'name': 'Restart Linux Services', 'flow_designer_flow': '', 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_view.do?v=1&sysparm_id=9ca5f701931b021005f472ba2bba108f&sysparm_preview=true", "summary");', 'template': '', 'short_description': 'Restart Linux Services', 'access_type': 'restricted', 'fulfillment_automation_level': 'unspecified', 'roles': '', 'icon': '', 'description': '<p>Restart Linux Services</p>', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item', 'sys_id': '9ca5f701931b021005f472ba2bba108f', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': 'use_desktop_picture', 'sys_scope': {'link': 'https://dev199703.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': {'link': 'https://dev199703.service-now.com/api/now/table/sys_user/6816f79cc0a8016401c5a33be04be441', 'value': '6816f79cc0a8016401c5a33be04be441'}, 'no_delivery_time_v2': 'false', 'cost': '0', 'no_quantity_v2': 'false', 'sys_mod_count': '24', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '', 'sys_package': {'link': 'https://dev199703.service-now.com/api/now/table/sys_package/global', 'value': 'global'}, 'display_price_property': 'non_zero', 'taxonomy_topic': '', 'delivery_plan_script': '', 'location': '', 'category': '', 'no_save_as_draft': 'false'}
# Catalog Item Name: Restart Linux Services
#
# Description:
# The "Restart Linux Services" catalog item allows users to manage the state of services on a specified Linux host. Users can restart, start, or stop services on a Linux system through a streamlined and user-friendly request form. This item is available on the desktop and is designed to facilitate the efficient management of Linux services.
#
# Variables (Fields):
# - **Requested For**: The user for whom the request is made (mandatory).
# - **Host Name**: The name of the host where the Linux service is running (mandatory).
# - **Service Name**: The name of the service to be managed (mandatory).
# - **Action Type**: The type of action to be performed on the service (mandatory). The available choices are:
#   - **Restart**: Restart the specified service.
#   - **Start**: Start the specified service.
#   - **Stop**: Stop the specified service.
# - **Additional Details**: Any additional information relevant to the request (optional).
#
# This catalog item ensures that users can easily manage Linux services by providing essential fields and clear options for the required actions. The mandatory fields ensure that all necessary information is collected to process the request efficiently.

# %%
isdir
# Out:
# False

# %%
docs = db2.similarity_search(query)
print(docs[0].page_content)
# Out:
# ```markdown
# Catalog Item Name: Software Services
#
# Description:
# The Software Services catalog item allows users to request various software-related services. This includes the following actions:
#
# - **Software Installation**: Users can request the installation of software such as Adobe Acrobat DC Pro or Python.
# - **Software Uninstallation**: Users can request the removal of existing software.
# - **OS Update**: Users can request updates to their operating systems.
#
# This item is available on the desktop and is designed to streamline the process of managing software needs efficiently.
#
# Variables (Fields):
# 1. **Requested for**: The user for whom the request is made (mandatory).
# 2. **Contact Number**: The contact number of the requester.
# 3. **Location**: The location of the requester.
# 4. **Project Name**: The department or project name associated with the request.
# 5. **Business Service**: The specific service being requested (Software Installation, Software Uninstallation, OS Upgrade).
# 6. **Software Name**: The specified software being requested (Adobe Acrobat DC Pro, Python).
# 7. **Add Software**: Option to add software.
# 8. **Request Type**: The type of request, e.g., Software Installation - Freeware.
# 9. **Duration**: The expected duration for the service.
# 10. **Correct Host Name**: Selection of the correct host name where the service will be applied.
#
# UI Policy Description:
# UI Policies define the visibility and behavior of certain fields based on the selected Business Service.
#
# **UI Policy for Software Installation**:
#
# - **Condition**:
#   - This policy is triggered if the Business Service field is set to "Software Installation".
# - **Actions**:
#   - When this condition is met, several fields related to the software installation process are made visible to the user.
#   - Fields affected by this policy include the Software Name, Request Type, Duration, and Add Software options.
#
# **UI Policy for Software Uninstallation**:
#
# - **Condition**:
#   - This policy is triggered if the Business Service field is set to "Software Uninstallation".
# - **Actions**:
#   - When this condition is met, fields related to the software uninstallation process are made visible.
#   - Specifically, the Software Name field will be visible, allowing users to select which software they wish to uninstall.
#
# These UI policies ensure that users only see and interact with fields relevant to the specific service they are requesting, enhancing the user experience by simplifying the form and reducing unnecessary complexity.
# ```

# %%
docs[0].metadata
# Out:
# {'sys_id': '4391de3e938b821005f472ba2bba1096', 'sys_name': 'Software Services'}

# %%
# load from disk
# db3 = Chroma(persist_directory="./chroma_db", embedding_function=embedding_function)
# docs = db3.similarity_search(query)
# print(docs[0].page_content)

# %%
docs
# Out:
# [Document(page_content='```markdown\nCatalog Item Name: Software Services\n\nDescription:\nThe Software Services catalog item allows users to request various software-related services. This includes the following actions:\n\n- **Software Installation**: Users can request the installation of software such as Adobe Acrobat DC Pro or Python.\n- **Software Uninstallation**: Users can request the removal of existing software.\n- **OS Update**: Users can request updates to their operating systems.\n\nThis item is available on the desktop and is designed to streamline the process of managing software needs efficiently.\n\nVariables (Fields):\n1. **Requested for**: The user for whom the request is made (mandatory).\n2. **Contact Number**: The contact number of the requester.\n3. **Location**: The location of the requester.\n4. **Project Name**: The department or project name associated with the request.\n5. **Business Service**: The specific service being requested (Software Installation, Software Uninstallation, OS Upgrade).\n6. **Software Name**: The specified software being requested (Adobe Acrobat DC Pro, Python).\n7. **Add Software**: Option to add software.\n8. **Request Type**: The type of request, e.g., Software Installation - Freeware.\n9. **Duration**: The expected duration for the service.\n10. **Correct Host Name**: Selection of the correct host name where the service will be applied.\n\nUI Policy Description:\nUI Policies define the visibility and behavior of certain fields based on the selected Business Service.\n\n**UI Policy for Software Installation**:\n\n- **Condition**:\n  - This policy is triggered if the Business Service field is set to "Software Installation".\n- **Actions**:\n  - When this condition is met, several fields related to the software installation process are made visible to the user.\n  - Fields affected by this policy include the Software Name, Request Type, Duration, and Add Software options.\n\n**UI Policy for Software Uninstallation**:\n\n- **Condition**:\n  - This policy is triggered if the Business Service field is set to "Software Uninstallation".\n- **Actions**:\n  - When this condition is met, fields related to the software uninstallation process are made visible.\n  - Specifically, the Software Name field will be visible, allowing users to select which software they wish to uninstall.\n\nThese UI policies ensure that users only see and interact with fields relevant to the specific service they are requesting, enhancing the user experience by simplifying the form and reducing unnecessary complexity.\n```', metadata={'sys_id': '4391de3e938b821005f472ba2bba1096', 'sys_name': 'Software Services'}),
#  Document(page_content='Catalog Item Name: Request Developer Project Equipment\n\nDescription:\nThe "Request Developer Project Equipment" catalog item allows users to request both hardware and software necessary to support a development project. This item is designed to streamline the process of obtaining the necessary equipment and software for development purposes efficiently and effectively.\n\nThis catalog item includes the following actions:\n\n1. Hardware Request: Users can request the necessary hardware for their development projects.\n2. Software Request: Users can request the required software to support their development activities.\n\nAvailability:\n- This item is available on desktop platforms.\n\nVariables (Fields):\n1. **Are you developing for Android or iOS?** (Select Box)\n   - Choices:\n     - Android\n     - iOS\n     - Both\n\n2. **What software do you require?** (List Collector)\n   - Allows users to select multiple software items from the catalog.\n\nThis catalog item includes options to specify the development platform (Android, iOS, or Both) and the specific software required for the project. By providing these details, users can ensure they receive the appropriate hardware and software to meet their development needs. The item is visible as a standalone option in the Service Catalog and includes features to show the delivery time and add items to a wishlist.\n\nUI Policy and Client Script:\nThere are no UI policies or client scripts defined for this catalog item, ensuring a straightforward and user-friendly experience.\n\nBy using this catalog item, developers can efficiently request the necessary tools to support their projects, ensuring they have the right resources to succeed.', metadata={'sys_id': '25110912372211003e7d40ed9dbe5dd6', 'sys_name': 'Request Developer Project Equipment'}),
#  Document(page_content='Catalog Item Name: Restart Linux Services\n\nDescription:\nThe "Restart Linux Services" catalog item allows users to manage the state of services on a specified Linux host. Users can restart, start, or stop services on a Linux system through a streamlined and user-friendly request form. This item is available on the desktop and is designed to facilitate the efficient management of Linux services.\n\nVariables (Fields):\n- **Requested For**: The user for whom the request is made (mandatory).\n- **Host Name**: The name of the host where the Linux service is running (mandatory).\n- **Service Name**: The name of the service to be managed (mandatory).\n- **Action Type**: The type of action to be performed on the service (mandatory). The available choices are:\n  - **Restart**: Restart the specified service.\n  - **Start**: Start the specified service.\n  - **Stop**: Stop the specified service.\n- **Additional Details**: Any additional information relevant to the request (optional).\n\nThis catalog item ensures that users can easily manage Linux services by providing essential fields and clear options for the required actions. The mandatory fields ensure that all necessary information is collected to process the request efficiently.', metadata={'sys_id': '9ca5f701931b021005f472ba2bba108f', 'sys_name': 'Restart Linux Services'}),
#  Document(page_content='Catalog Item Name: New Hire Order Guide\n\nDescription:\nThe New Hire Order Guide catalog item is designed to streamline the onboarding process for new employees, ensuring they are equipped with the necessary tools and access to be productive from day one. The package includes tasks such as hardware provisioning, software access, and account creation. Unless specified otherwise, all new employees receive the standard package outlined below.\n\nService Overview:\n- **Email account creation**\n- **Hardware**: Lenovo Carbon x1 and one external monitor\n- **Software**: MS Office Suite including Outlook, Word, PowerPoint, Excel, and OneNote\n\nThis item is available on the desktop and is tailored to ensure a smooth and efficient onboarding process.\n\nVariables (Fields):\n1. **Hiring Manager**: The system administrator or user responsible for the new hire (mandatory).\n2. **What group is this person joining**: The department or group the new hire will be part of (mandatory).\n3. **Will this be a remote employee?**: Yes/No option to indicate if the employee will be working remotely (mandatory). Choices:\n   - Yes\n   - No\n4. **What office will they report to**: The physical office location where the new hire will report (optional).\n5. **Will your employee need anything non-standard?**: Yes/No option to specify if the new hire requires any non-standard equipment or software (mandatory). Choices:\n   - Yes\n   - No\n6. **What Device Type**: The type of laptop required for the new hire (optional). Choices:\n   - Developer\n   - Sales\n7. **Mobile Device Type**: The type of mobile device required (optional). Choices:\n   - -- None --\n   - iPhone\n   - Android\n\nUI Policy Description:\nUI Policies are in place to control the visibility and behavior of certain fields based on user selections.\n\n1. **Default Values for Developers**: This policy sets default values specifically for developers.\n   \n2. **Hide Device Type and other attributes**:\n   - **Condition**: This policy is triggered if the field "Will your employee need anything non-standard?" is set to "No".\n   - **Actions**: When the condition is met, the fields for mobile device type and laptop type are hidden from the form.\n\nThese UI policies ensure a streamlined user experience by displaying only the relevant fields based on the specific needs of the new hire, thereby reducing unnecessary complexity and enhancing the efficiency of the onboarding process.', metadata={'sys_id': '6690750f4f7b4200086eeed18110c761', 'sys_name': 'New Hire'})]

# %%
# load from disk
db3 = Chroma(persist_directory="./chroma_db", embedding_function=embedding_function)
docs = db3.similarity_search(query)
print(docs[0].page_content)
# Out:
# ```markdown
# Catalog Item Name: Software Services
#
# Description:
# The Software Services catalog item allows users to request various software-related services. This includes the following actions:
#
# - **Software Installation**: Users can request the installation of software such as Adobe Acrobat DC Pro or Python.
# - **Software Uninstallation**: Users can request the removal of existing software.
# - **OS Update**: Users can request updates to their operating systems.
#
# This item is available on the desktop and is designed to streamline the process of managing software needs efficiently.
#
# Variables (Fields):
# 1. **Requested for**: The user for whom the request is made (mandatory).
# 2. **Contact Number**: The contact number of the requester.
# 3. **Location**: The location of the requester.
# 4. **Project Name**: The department or project name associated with the request.
# 5. **Business Service**: The specific service being requested (Software Installation, Software Uninstallation, OS Upgrade).
# 6. **Software Name**: The specified software being requested (Adobe Acrobat DC Pro, Python).
# 7. **Add Software**: Option to add software.
# 8. **Request Type**: The type of request, e.g., Software Installation - Freeware.
# 9. **Duration**: The expected duration for the service.
# 10. **Correct Host Name**: Selection of the correct host name where the service will be applied.
#
# UI Policy Description:
# UI Policies define the visibility and behavior of certain fields based on the selected Business Service.
#
# **UI Policy for Software Installation**:
#
# - **Condition**:
#   - This policy is triggered if the Business Service field is set to "Software Installation".
# - **Actions**:
#   - When this condition is met, several fields related to the software installation process are made visible to the user.
#   - Fields affected by this policy include the Software Name, Request Type, Duration, and Add Software options.
#
# **UI Policy for Software Uninstallation**:
#
# - **Condition**:
#   - This policy is triggered if the Business Service field is set to "Software Uninstallation".
# - **Actions**:
#   - When this condition is met, fields related to the software uninstallation process are made visible.
#   - Specifically, the Software Name field will be visible, allowing users to select which software they wish to uninstall.
#
# These UI policies ensure that users only see and interact with fields relevant to the specific service they are requesting, enhancing the user experience by simplifying the form and reducing unnecessary complexity.
# ```
