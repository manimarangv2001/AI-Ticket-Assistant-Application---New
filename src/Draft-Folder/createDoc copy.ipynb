# %%
import requests
import os
from langchain.docstore.document import Document
from langchain_openai import AzureOpenAIEmbeddings, AzureChatOpenAI 
from langchain_core.output_parsers import JsonOutputParser, StrOutputParser
from langchain_core.prompts import PromptTemplate
from langchain_chroma import Chroma

# %%
embedding_function = AzureOpenAIEmbeddings(
    azure_endpoint="https://2000081253-openai.openai.azure.com/",
    api_key="107c20f6b6774c80b98c6f6a828f6374",
    azure_deployment="Text-embedding",
    api_version="2023-03-15-preview"
    )

# %%
model = AzureChatOpenAI(
    api_key="107c20f6b6774c80b98c6f6a828f6374",
    azure_deployment="gpt-4",
    azure_endpoint="https://2000081253-openai.openai.azure.com/",
    api_version="2023-03-15-preview"
)

# %%
base_url = os.environ["SERVICENOW_BASEURL"]
user = os.environ["SERVICENOW_USERNAME"]
pwd = os.environ["SERVICENOW_PASSWORD"]
headers = {"Content-Type":"application/json","Accept":"application/json"}

def get_catalog_item_collection():
    url = f'{base_url}/now/table/sc_cat_item?sysparm_query=sc_catalogsLIKEe0d08b13c3330100c8b837659bba8fb4%5Eactive%3Dtrue'
    response = requests.get(url, auth=(user, pwd), headers=headers )
    if response.status_code != 200: 
        data = {'result':{'sys_id': "", 'sys_name': "",'short_description':"",'description':""}, 'Status': response.status_code, 'Headers': response.headers, 'Error Response':response.json()}
    data = response.json()
    return data


def get_catalog_item(sys_id):
    url = f'{base_url}/sn_sc/servicecatalog/items/{sys_id}'
    response = requests.get(url, auth=(user, pwd), headers=headers )
    if response.status_code != 200: 
        print('Status:', response.status_code, 'Headers:', response.headers, 'Error Response:',response.json())
    data = response.json()
    return data

def get_table_values(reference):
    url = f'{base_url}/now/table/{reference}'
    response = requests.get(url, auth=(user, pwd), headers=headers )
    if response.status_code != 200: 
        print('Status:', response.status_code, 'Headers:', response.headers, 'Error Response:',response.json())
        exit()
    data = response.json()
    return data

def get_ref_qualifier_script(class_name):
    url = f'{base_url}/1353990/script_includes/script_include/{class_name}'

    response = requests.get(url, auth=(user, pwd), headers=headers )
    if response.status_code != 200: 
        print('Status:', response.status_code, 'Headers:', response.headers, 'Error Response:',response.json())
        exit()

    data = response.json()
    print(data)

# %%
def descriptionMaker(data):

    print(data)

    template = """{data}
    
    using this data provide a proper description for this catalog item.
    also it should contain variable(parent and child) and variable description.
    In the Json data, If variables have reference_values, mention all of it in variable description.
    In the Json data, If variables have choices, mention all of it in variable description.
    The variables description should mention the ui policy condtions and actions if exist.
    The variables description should mention the reference qualifier.
    It should not contain other then that.
    
    Format:
    Catalog Item Name: Name of the catalog item
    Description: detailed description about catalog item.
    Variables (Fields):
    Name of the variable: About the variable.
    """
    
    prompt_template = PromptTemplate(template=template, input_variables=["data"])
    chain = prompt_template | model
    response = chain.invoke({"data": data})
    return response

# %%
catalog_item_collection = get_catalog_item_collection()

# %%
def set_reference_value(variable):
    if(variable['type'] == 8 and variable['dynamic_value_field'] == ''):
        reference = variable['reference']
        table_content = get_table_values(reference=reference)
        # print(table_content)
        names_in_table = []
        for content in table_content['result']:
            if('u_name' in content):
                names_in_table.append(content['u_name'])
            elif('name' in content):
                names_in_table.append(content['name'])
        variable['Choices'] = list(set(names_in_table))
        print(variable)
        return variable
    else:
        return variable
    

def get_all_variables_List(catalog_item_variable):
    def extract_variables(variables):
        variable_List = []
        for variable_info in variables:
            if variable_info['type'] == 24:
                continue
            if 'children' in variable_info:
                variable_List.extend(extract_variables(variable_info['children']))
            else:
                variable_List.append(variable_info)
        return variable_List
    
    return extract_variables(catalog_item_variable)




def arrange_response(catalog_item_json):
    print(catalog_item_json)
    variables = catalog_item_json['result']['variables']
    new_variables = get_all_variables_List(variables)
    final_result = []
    for variable in new_variables:
        if variable['type'] == 11:
            continue
        else:
            final_result.append(set_reference_value(variable))
    catalog_item_json['result']['variables'] = final_result
    return catalog_item_json

# %%
def createDocuments():
    docs=[]
    for catalog_item in catalog_item_collection['result']:
        if(catalog_item['sys_class_name'] != 'sc_cat_item'):
            continue
        if(catalog_item['sys_id'] != '39dbfcc3c3489a1068d8b132b4013167'):# '50572ffac3405a1068d8b132b4013177'):
            continue
        print(catalog_item)
        metadata = {"sys_id":catalog_item['sys_id'], "sys_name":catalog_item['sys_name'], "short_description":catalog_item["short_description"]}
        catalog_item_json = arrange_response(get_catalog_item(catalog_item['sys_id']))
        description = descriptionMaker(catalog_item_json)
        docs.append(Document(page_content=description.content, metadata=metadata))
        print(description.content)
    return docs

# %%
# from langchain_pinecone import PineconeVectorStore

# docsearch = PineconeVectorStore.from_documents(docs, embeddings, index_name=index_name)

# %%
query = "I need to install python"

# %%
path = './catalog_item_db'
isdir = os.path.isdir(path)
if(not isdir):
    db2 = Chroma.from_documents(documents=createDocuments(), embedding=embedding_function, persist_directory=path)
# Out:
# {'entitlement_script': '', 'use_sc_layout': 'true', 'show_variable_help_on_load': 'false', 'no_order_now': 'false', 'sc_ic_version': '', 'delivery_time': '1970-01-03 00:00:00', 'sys_updated_on': '2024-09-01 20:19:47', 'type': 'item', 'published_ref': '', 'no_search': 'false', 'sys_updated_by': 'system', 'price': '0', 'sys_created_on': '2024-08-20 12:43:10', 'recurring_frequency': '', 'sys_name': 'Report IT Incidents', 'model': '', 'state': '', 'no_cart': 'false', 'sys_created_by': 'admin', 'group': '', 'hide_sp': 'false', 'order': '0', 'start_closed': 'false', 'image': '', 'no_quantity': 'false', 'workflow': '', 'delivery_plan': {'link': 'https://dev203505.service-now.com/api/now/table/sc_cat_item_delivery_plan/523da512c611228900811a37c97c2014', 'value': '523da512c611228900811a37c97c2014'}, 'active': 'true', 'checked_out': '', 'custom_cart': '', 'no_cart_v2': 'false', 'no_proceed_checkout': 'false', 'version': '62', 'ignore_price': 'true', 'sys_update_name': 'sc_cat_item_39dbfcc3c3489a1068d8b132b4013167', 'meta': '', 'omit_price': 'false', 'name': 'Report IT Incidents', 'flow_designer_flow': '', 'mobile_hide_price': 'false', 'no_wishlist_v2': 'false', 'sys_policy': '', 'preview': 'JavaScript: popupOpenStandard("com.glideapp.servicecatalog_cat_item_view.do?v=1&sysparm_id=39dbfcc3c3489a1068d8b132b4013167&sysparm_preview=true", "summary");', 'template': '', 'short_description': 'Get support with STG issues that you are facing', 'access_type': 'restricted', 'fulfillment_automation_level': 'unspecified', 'roles': '', 'icon': '', 'description': '', 'mobile_picture': '', 'sc_template': '', 'availability': 'on_desktop', 'mandatory_attachment': 'false', 'request_method': '', 'visible_guide': 'true', 'visible_standalone': 'true', 'sys_class_name': 'sc_cat_item', 'sys_id': '39dbfcc3c3489a1068d8b132b4013167', 'no_order': 'false', 'vendor': '', 'no_attachment_v2': 'false', 'mobile_picture_type': 'use_desktop_picture', 'sys_scope': {'link': 'https://dev203505.service-now.com/api/now/table/sys_scope/global', 'value': 'global'}, 'visible_bundle': 'true', 'sc_catalogs': 'e0d08b13c3330100c8b837659bba8fb4', 'make_item_non_conversational': 'false', 'ordered_item_link': '', 'owner': {'link': 'https://dev203505.service-now.com/api/now/table/sys_user/6816f79cc0a8016401c5a33be04be441', 'value': '6816f79cc0a8016401c5a33be04be441'}, 'no_delivery_time_v2': 'false', 'cost': '0', 'no_quantity_v2': 'false', 'sys_mod_count': '62', 'recurring_price': '0', 'list_price': '0', 'sc_ic_item_staging': '', 'sys_tags': '', 'billable': 'false', 'picture': '', 'sys_package': {'link': 'https://dev203505.service-now.com/api/now/table/sys_package/global', 'value': 'global'}, 'display_price_property': 'non_zero', 'taxonomy_topic': '', 'delivery_plan_script': '', 'location': '', 'category': '', 'no_save_as_draft': 'false'}
# {'result': {'short_description': 'Get support with STG issues that you are facing', 'kb_article': '', 'icon': 'images/service_catalog/generic_small.gifx', 'description': '', 'availability': 'on_desktop', 'mandatory_attachment': False, 'request_method': '', 'type': 'catalog_item', 'visible_standalone': True, 'sys_class_name': 'sc_cat_item', 'sys_id': '39dbfcc3c3489a1068d8b132b4013167', 'content_type': '', 'order': 0, 'make_item_non_conversational': False, 'owner': '6816f79cc0a8016401c5a33be04be441', 'show_price': False, 'show_quantity': True, 'picture': '', 'url': '', 'catalogs': [{'sys_id': 'e0d08b13c3330100c8b837659bba8fb4', 'active': True, 'title': 'Service Catalog'}], 'name': 'Report IT Incidents', 'show_wishlist': True, 'category': {'sys_id': '', 'title': None}, 'turn_off_nowassist_conversation': False, 'show_delivery_time': True, 'categories': [], 'variables': [{'active': True, 'label': "Requestor's Information", 'dynamic_value_field': '', 'type': 11, 'mandatory': False, 'displayvalue': '', 'friendly_type': 'label', 'display_type': 'Label', 'render_label': True, 'read_only': False, 'name': 'requestor_s_information', 'attributes': 'edge_encryption_enabled=true', 'id': '805e7c03c3889a1068d8b132b4013138', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': -1}, {'containerSplitId': 'd68c3c07c3489a1068d8b132b401312e', 'type': 19, 'mandatory': False, 'friendly_type': 'container_start', 'display_type': 'Container Start', 'read_only': False, 'children': [{'active': True, 'label': 'Reported For', 'dynamic_value_field': '', 'type': 31, 'mandatory': True, 'displayvalue': 'System Administrator', 'friendly_type': 'requested_for', 'display_type': 'Requested For', 'reference': 'sys_user', 'render_label': True, 'ref_qualifier': 'EQ', 'read_only': False, 'name': 'reported_for', 'attributes': 'edge_encryption_enabled=true', 'id': '6ddcfc07c3489a1068d8b132b401314d', 'value': 'javascript:gs.getUserID();', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 1}, {'active': True, 'label': 'Location', 'dynamic_value_field': '6ddcfc07c3489a1068d8b132b401314d', 'type': 8, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'reference', 'display_type': 'Reference', 'reference': 'cmn_location', 'render_label': True, 'ref_qualifier': '', 'read_only': False, 'name': 'location', 'attributes': 'edge_encryption_enabled=true', 'id': 'ba2d788bc3489a1068d8b132b4013182', 'value': '', 'dynamic_value_dot_walk_path': 'location', 'help_text': '', 'max_length': 0, 'order': 2}, {'active': True, 'label': None, 'dynamic_value_field': '', 'type': 24, 'mandatory': False, 'displayvalue': '', 'friendly_type': 'container_split', 'display_type': 'Container Split', 'render_label': True, 'read_only': False, 'name': 'formatter', 'attributes': 'edge_encryption_enabled=true', 'id': 'd68c3c07c3489a1068d8b132b401312e', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 3}, {'active': True, 'label': 'Contact Number', 'dynamic_value_field': '', 'type': 6, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'single_line_text', 'display_type': 'Single Line Text', 'render_label': True, 'read_only': False, 'name': 'contact_number', 'attributes': 'edge_encryption_enabled=true', 'id': 'aa0df0c3c3489a1068d8b132b4013118', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 4}, {'active': True, 'label': 'Project', 'dynamic_value_field': '6ddcfc07c3489a1068d8b132b401314d', 'type': 8, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'reference', 'display_type': 'Reference', 'reference': 'cmn_department', 'render_label': True, 'ref_qualifier': '', 'read_only': False, 'name': 'project', 'attributes': 'edge_encryption_enabled=true', 'id': 'fa6df4cbc3489a1068d8b132b40131b4', 'value': '', 'dynamic_value_dot_walk_path': 'department', 'help_text': '', 'max_length': 0, 'order': 5}, {'active': True, 'label': 'Building', 'dynamic_value_field':  ...
# {'active': True, 'label': 'Service', 'dynamic_value_field': '', 'type': 8, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'reference', 'display_type': 'Reference', 'reference': 'u_service', 'render_label': True, 'ref_qualifier': 'u_parent_fieldISEMPTY^EQ', 'read_only': False, 'name': 'service', 'attributes': 'edge_encryption_enabled=true', 'id': '502ff80bc3889a1068d8b132b4013144', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 9, 'Choices': ['Access Related issue', 'Visa Requisition', 'Microsoft Office', 'Voice Instance', 'Call Flow', 'Account Unlock', 'Inbound Call', 'Skype / Teams', 'Desktop', 'Computer Accessories', 'Hardware', 'IIS Operations Support', 'Virtualization', 'DC Ops Services', 'Access', 'Touch panal issue', 'Plan Arena', 'Video Conferencing', 'Recording', 'Network Services', 'SPAM Email', 'Switch', 'Router', 'Email', 'Verint', 'Attendance Tracker', 'SLAs', 'Email Services', 'Data Card', 'Memory', 'Application Issue', 'Wireless Controller', 'Unable to find Recordings or Deleted rec', 'CPPM', 'Mail Delivery Issue', 'SFTP (Secure File Transfer Protocol)', 'Microphone issue', 'Peripheral Devices', 'IVR (Interactive Voice Response)', 'Reports', 'Nice', 'Voice Services', 'Slowness issue', 'Service Request', 'Voice Quality', 'Break - Fix', 'IP Phone', 'CPU', 'Active Sync', 'Content sharing issue', 'VPN Related Issues', 'Keyboard', 'Browser', 'Availability', 'Module', 'Camera issue', 'Application or Database Alerts', 'Hex_EY VPN Related Issues', 'Virtual Server - Linux', 'MS Outlook', 'Full and Final Settlement', 'Antivirus Updates', 'Cloud Ops', 'Network alerts', 'Printer', 'AskGenie', 'MY HR', 'User Account Management', 'Reporting', 'Application Services', 'Agent Login', 'User account disable - Batch job failure', 'Webex', 'Board Room', 'Backup / Restore', 'Mobile Device', 'Server Management', 'Printer / Scanner', 'NetArch 9', 'Physical Server - Linux', 'Connectivity issue', 'Storage', 'Asset Allocation Issues', 'Azure/Aws/GCP ticket creation', 'Port', 'VPN', 'CRM', 'Other Accessories', 'Service down', 'File Transfer', 'RMG Portal', 'Agent', 'Others', 'Time & Billing', 'Password Reset', 'e-Voice', 'EPayroll', 'Switch / Router', 'Data', 'Scanner', 'Alerts Monitoring', 'Performance Issue', 'Server or Cloud Alerts', 'CUIC', 'Other Software', 'Error', 'User name / Email ID changes for existin', 'People Soft Finance', 'Software', 'InactiveTerminalSessions', 'Slow', 'Other', 'Laptop', 'NIC (Network Interface Card)', 'MyBenefits', 'Anti Virus', 'IT Proof', 'VC room', 'CPU Utilization', 'Virtual Server - Windows', 'Service Operations', 'Kramer Room scheduler not working', 'Virus Infection', 'Mouse', 'Login Issues', 'WiFi', 'Down', 'ART', 'Database', 'Application', 'Firmware', 'Operating System', 'Audio issue', 'Video Conference', 'PeopleSoft HRMS', 'End user computing (Deskside) services', 'Expense Claim System', 'Audio Quality issues in WebEx Meeting', 'Outbound Call', 'Citrix', 'Vendor Payment System', 'Patch Management', 'Webex Login Issue', 'Finesse', 'Memory Utilization', 'Clearance Process', 'Revenue Tracker', 'Firewall', 'Clouds VM maintenance', 'DAT update', 'Customer Delight', 'Links', 'AskGenie Administration', 'SVN', 'DID Mapping', 'Hunt Group Call Landing', 'Windows Updates', 'Compass', 'ION', 'Physical Server - Windows', 'Stationh Admin', 'Other Applications', 'Allowances', 'Internet Connectivity', 'Global Protect VPN', 'Mobile App', 'Diskspace Utilization', 'Disk Clean Up', 'Performance']}
# {'active': True, 'label': 'Category', 'dynamic_value_field': '', 'type': 8, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'reference', 'display_type': 'Reference', 'reference': 'u_service', 'render_label': True, 'ref_qualifier': 'javascript:new ShowCatagory().catagory()', 'read_only': False, 'name': 'category', 'attributes': 'edge_encryption_enabled=true', 'id': '837fb4cfc3889a1068d8b132b4013113', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 10, 'Choices': ['Access Related issue', 'Visa Requisition', 'Microsoft Office', 'Voice Instance', 'Call Flow', 'Account Unlock', 'Inbound Call', 'Skype / Teams', 'Desktop', 'Computer Accessories', 'Hardware', 'IIS Operations Support', 'Virtualization', 'DC Ops Services', 'Access', 'Touch panal issue', 'Plan Arena', 'Video Conferencing', 'Recording', 'Network Services', 'SPAM Email', 'Switch', 'Router', 'Email', 'Verint', 'Attendance Tracker', 'SLAs', 'Email Services', 'Data Card', 'Memory', 'Application Issue', 'Wireless Controller', 'Unable to find Recordings or Deleted rec', 'CPPM', 'Mail Delivery Issue', 'SFTP (Secure File Transfer Protocol)', 'Microphone issue', 'Peripheral Devices', 'IVR (Interactive Voice Response)', 'Reports', 'Nice', 'Voice Services', 'Slowness issue', 'Service Request', 'Voice Quality', 'Break - Fix', 'IP Phone', 'CPU', 'Active Sync', 'Content sharing issue', 'VPN Related Issues', 'Keyboard', 'Browser', 'Availability', 'Module', 'Camera issue', 'Application or Database Alerts', 'Hex_EY VPN Related Issues', 'Virtual Server - Linux', 'MS Outlook', 'Full and Final Settlement', 'Antivirus Updates', 'Cloud Ops', 'Network alerts', 'Printer', 'AskGenie', 'MY HR', 'User Account Management', 'Reporting', 'Application Services', 'Agent Login', 'User account disable - Batch job failure', 'Webex', 'Board Room', 'Backup / Restore', 'Mobile Device', 'Server Management', 'Printer / Scanner', 'NetArch 9', 'Physical Server - Linux', 'Connectivity issue', 'Storage', 'Asset Allocation Issues', 'Azure/Aws/GCP ticket creation', 'Port', 'VPN', 'CRM', 'Other Accessories', 'Service down', 'File Transfer', 'RMG Portal', 'Agent', 'Others', 'Time & Billing', 'Password Reset', 'e-Voice', 'EPayroll', 'Switch / Router', 'Data', 'Scanner', 'Alerts Monitoring', 'Performance Issue', 'Server or Cloud Alerts', 'CUIC', 'Other Software', 'Error', 'User name / Email ID changes for existin', 'People Soft Finance', 'Software', 'InactiveTerminalSessions', 'Slow', 'Other', 'Laptop', 'NIC (Network Interface Card)', 'MyBenefits', 'Anti Virus', 'IT Proof', 'VC room', 'CPU Utilization', 'Virtual Server - Windows', 'Service Operations', 'Kramer Room scheduler not working', 'Virus Infection', 'Mouse', 'Login Issues', 'WiFi', 'Down', 'ART', 'Database', 'Application', 'Firmware', 'Operating System', 'Audio issue', 'Video Conference', 'PeopleSoft HRMS', 'End user computing (Deskside) services', 'Expense Claim System', 'Audio Quality issues in WebEx Meeting', 'Outbound Call', 'Citrix', 'Vendor Payment System', 'Patch Management', 'Webex Login Issue', 'Finesse', 'Memory Utilization', 'Clearance Process', 'Revenue Tracker', 'Firewall', 'Clouds VM maintenance', 'DAT update', 'Customer Delight', 'Links', 'AskGenie Administration', 'SVN', 'DID Mapping', 'Hunt Group Call Landing', 'Windows Updates', 'Compass', 'ION', 'Physical Server - Windows', 'Stationh Admin', 'Other Applications', 'Allowances', 'Internet Connectivity', 'Global Protect VPN', 'Mobile App', 'Diskspace Utilization', 'Disk Clean Up', 'Performance']}
# {'active': True, 'label': 'Child Category 1', 'dynamic_value_field': '', 'type': 8, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'reference', 'display_type': 'Reference', 'reference': 'u_service', 'render_label': True, 'ref_qualifier': 'javascript:new ShowCatagory().childCatagory()', 'read_only': False, 'name': 'child_category_1', 'attributes': 'edge_encryption_enabled=true,ref_qual_elements=category', 'id': '24b6c5c7c34c9a1068d8b132b401316d', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 11, 'Choices': ['Access Related issue', 'Visa Requisition', 'Microsoft Office', 'Voice Instance', 'Call Flow', 'Account Unlock', 'Inbound Call', 'Skype / Teams', 'Desktop', 'Computer Accessories', 'Hardware', 'IIS Operations Support', 'Virtualization', 'DC Ops Services', 'Access', 'Touch panal issue', 'Plan Arena', 'Video Conferencing', 'Recording', 'Network Services', 'SPAM Email', 'Switch', 'Router', 'Email', 'Verint', 'Attendance Tracker', 'SLAs', 'Email Services', 'Data Card', 'Memory', 'Application Issue', 'Wireless Controller', 'Unable to find Recordings or Deleted rec', 'CPPM', 'Mail Delivery Issue', 'SFTP (Secure File Transfer Protocol)', 'Microphone issue', 'Peripheral Devices', 'IVR (Interactive Voice Response)', 'Reports', 'Nice', 'Voice Services', 'Slowness issue', 'Service Request', 'Voice Quality', 'Break - Fix', 'IP Phone', 'CPU', 'Active Sync', 'Content sharing issue', 'VPN Related Issues', 'Keyboard', 'Browser', 'Availability', 'Module', 'Camera issue', 'Application or Database Alerts', 'Hex_EY VPN Related Issues', 'Virtual Server - Linux', 'MS Outlook', 'Full and Final Settlement', 'Antivirus Updates', 'Cloud Ops', 'Network alerts', 'Printer', 'AskGenie', 'MY HR', 'User Account Management', 'Reporting', 'Application Services', 'Agent Login', 'User account disable - Batch job failure', 'Webex', 'Board Room', 'Backup / Restore', 'Mobile Device', 'Server Management', 'Printer / Scanner', 'NetArch 9', 'Physical Server - Linux', 'Connectivity issue', 'Storage', 'Asset Allocation Issues', 'Azure/Aws/GCP ticket creation', 'Port', 'VPN', 'CRM', 'Other Accessories', 'Service down', 'File Transfer', 'RMG Portal', 'Agent', 'Others', 'Time & Billing', 'Password Reset', 'e-Voice', 'EPayroll', 'Switch / Router', 'Data', 'Scanner', 'Alerts Monitoring', 'Performance Issue', 'Server or Cloud Alerts', 'CUIC', 'Other Software', 'Error', 'User name / Email ID changes for existin', 'People Soft Finance', 'Software', 'InactiveTerminalSessions', 'Slow', 'Other', 'Laptop', 'NIC (Network Interface Card)', 'MyBenefits', 'Anti Virus', 'IT Proof', 'VC room', 'CPU Utilization', 'Virtual Server - Windows', 'Service Operations', 'Kramer Room scheduler not working', 'Virus Infection', 'Mouse', 'Login Issues', 'WiFi', 'Down', 'ART', 'Database', 'Application', 'Firmware', 'Operating System', 'Audio issue', 'Video Conference', 'PeopleSoft HRMS', 'End user computing (Deskside) services', 'Expense Claim System', 'Audio Quality issues in WebEx Meeting', 'Outbound Call', 'Citrix', 'Vendor Payment System', 'Patch Management', 'Webex Login Issue', 'Finesse', 'Memory Utilization', 'Clearance Process', 'Revenue Tracker', 'Firewall', 'Clouds VM maintenance', 'DAT update', 'Customer Delight', 'Links', 'AskGenie Administration', 'SVN', 'DID Mapping', 'Hunt Group Call Landing', 'Windows Updates', 'Compass', 'ION', 'Physical Server - Windows', 'Stationh Admin', 'Other Applications', 'Allowances', 'Internet Connectivity', 'Global Protect VPN', 'Mobile App', 'Diskspace Utilization', 'Disk Clean Up', 'Performance']}
# {'result': {'short_description': 'Get support with STG issues that you are facing', 'kb_article': '', 'icon': 'images/service_catalog/generic_small.gifx', 'description': '', 'availability': 'on_desktop', 'mandatory_attachment': False, 'request_method': '', 'type': 'catalog_item', 'visible_standalone': True, 'sys_class_name': 'sc_cat_item', 'sys_id': '39dbfcc3c3489a1068d8b132b4013167', 'content_type': '', 'order': 0, 'make_item_non_conversational': False, 'owner': '6816f79cc0a8016401c5a33be04be441', 'show_price': False, 'show_quantity': True, 'picture': '', 'url': '', 'catalogs': [{'sys_id': 'e0d08b13c3330100c8b837659bba8fb4', 'active': True, 'title': 'Service Catalog'}], 'name': 'Report IT Incidents', 'show_wishlist': True, 'category': {'sys_id': '', 'title': None}, 'turn_off_nowassist_conversation': False, 'show_delivery_time': True, 'categories': [], 'variables': [{'active': True, 'label': 'Reported For', 'dynamic_value_field': '', 'type': 31, 'mandatory': True, 'displayvalue': 'System Administrator', 'friendly_type': 'requested_for', 'display_type': 'Requested For', 'reference': 'sys_user', 'render_label': True, 'ref_qualifier': 'EQ', 'read_only': False, 'name': 'reported_for', 'attributes': 'edge_encryption_enabled=true', 'id': '6ddcfc07c3489a1068d8b132b401314d', 'value': 'javascript:gs.getUserID();', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 1}, {'active': True, 'label': 'Location', 'dynamic_value_field': '6ddcfc07c3489a1068d8b132b401314d', 'type': 8, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'reference', 'display_type': 'Reference', 'reference': 'cmn_location', 'render_label': True, 'ref_qualifier': '', 'read_only': False, 'name': 'location', 'attributes': 'edge_encryption_enabled=true', 'id': 'ba2d788bc3489a1068d8b132b4013182', 'value': '', 'dynamic_value_dot_walk_path': 'location', 'help_text': '', 'max_length': 0, 'order': 2}, {'active': True, 'label': 'Contact Number', 'dynamic_value_field': '', 'type': 6, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'single_line_text', 'display_type': 'Single Line Text', 'render_label': True, 'read_only': False, 'name': 'contact_number', 'attributes': 'edge_encryption_enabled=true', 'id': 'aa0df0c3c3489a1068d8b132b4013118', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 4}, {'active': True, 'label': 'Project', 'dynamic_value_field': '6ddcfc07c3489a1068d8b132b401314d', 'type': 8, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'reference', 'display_type': 'Reference', 'reference': 'cmn_department', 'render_label': True, 'ref_qualifier': '', 'read_only': False, 'name': 'project', 'attributes': 'edge_encryption_enabled=true', 'id': 'fa6df4cbc3489a1068d8b132b40131b4', 'value': '', 'dynamic_value_dot_walk_path': 'department', 'help_text': '', 'max_length': 0, 'order': 5}, {'active': True, 'label': 'Building', 'dynamic_value_field': '', 'type': 6, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'single_line_text', 'display_type': 'Single Line Text', 'render_label': True, 'read_only': False, 'name': 'Building', 'attributes': 'edge_encryption_enabled=true', 'id': 'd8bdbccbc3489a1068d8b132b401314f', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 6}, {'active': True, 'label': 'Service', 'dynamic_value_field': '', 'type': 8, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'reference', 'display_type': 'Reference', 'reference': 'u_service', 'render_label': True, 'ref_qualifier': 'u_parent_fieldISEMPTY^EQ', 'read_only': False, 'name': 'service', 'attributes': 'edge_encryption_enabled=true', 'id': '502ff80bc3889a1068d8b132b4013144', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 9, 'Choices': ['Access Related issue', 'Visa Requisition', 'Microsoft Office', 'Voice Instance', 'Call Flow', 'Account Unlock', 'Inbound Call', 'Skype / Teams', 'Desktop', 'Computer Accessories', 'Hardware', ' ...
# **Catalog Item Name:** Report IT Incidents
#
# **Description:** This catalog item allows users to report IT incidents they are experiencing and seek assistance for specific issues. The submission form gathers essential details to ensure the incident is accurately logged and addressed promptly.
#
# **Variables (Fields):**
#
# 1. **Reported For:** This field captures the user for whom the incident is being reported.
#    - **Type:** Requested For
#    - **Reference:** `sys_user`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Mandatory:** Yes
#    - **Dynamic Value:** `javascript:gs.getUserID();`
#
# 2. **Location:** This field captures the location of the user reporting the incident.
#    - **Type:** Reference
#    - **Reference:** `cmn_location`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Dynamic Value Field:** `reported_for`
#    - **Dynamic Value Dot Walk Path:** `location`
#    - **Mandatory:** Yes
#
# 3. **Contact Number:** This field captures the contact number of the user reporting the incident.
#    - **Type:** Single Line Text
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Mandatory:** Yes
#
# 4. **Project:** This field captures the project or department associated with the incident.
#    - **Type:** Reference
#    - **Reference:** `cmn_department`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Dynamic Value Field:** `reported_for`
#    - **Dynamic Value Dot Walk Path:** `department`
#    - **Mandatory:** Yes
#
# 5. **Building:** This field captures the building name or number where the incident occurred.
#    - **Type:** Single Line Text
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Mandatory:** Yes
#
# 6. **Service:** This field captures the specific service related to the incident.
#    - **Type:** Reference
#    - **Reference:** `u_service`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Reference Qualifier:** `u_parent_fieldISEMPTY^EQ`
#    - **Choices:**
#      - Access Related issue
#      - Visa Requisition
#      - Microsoft Office
#      - Voice Instance
#      - Call Flow
#      - Account Unlock
#      - Inbound Call
#      - Skype / Teams
#      - Desktop
#      - Computer Accessories
#      - Hardware
#      - IIS Operations Support
#      - Virtualization
#      - DC Ops Services
#      - Access
#      - Touch panal issue
#      - Plan Arena
#      - Video Conferencing
#      - Recording
#      - Network Services
#      - SPAM Email
#      - Switch
#      - Router
#      - Email
#      - Verint
#      - Attendance Tracker
#      - SLAs
#      - Email Services
#      - Data Card
#      - Memory
#      - Application Issue
#      - Wireless Controller
#      - Unable to find Recordings or Deleted rec
#      - CPPM
#      - Mail Delivery Issue
#      - SFTP (Secure File Transfer Protocol)
#      - Microphone issue
#      - Peripheral Devices
#      - IVR (Interactive Voice Response)
#      - Reports
#      - Nice
#      - Voice Services
#      - Slowness issue
#      - Service Request
#      - Voice Quality
#      - Break - Fix
#      - IP Phone
#      - CPU
#      - Active Sync
#      - Content sharing issue
#      - VPN Related Issues
#      - Keyboard
#      - Browser
#      - Availability
#      - Module
#      - Camera issue
#      - Application or Database Alerts
#      - Hex_EY VPN Related Issues
#      - Virtual Server - Linux
#      - MS Outlook
#      - Full and Final Settlement
#      - Antivirus Updates
#      - Cloud Ops
#      - Network alerts
#      - Printer
#      - AskGenie
#      - MY HR
#      - User Account Management
#      - Reporting
#      - Application Services
#      - Agent Login
#      - User account disable - Batch job failure
#      - Webex
#      - Board Room
#      - Backup / Restore
#      - Mobile Device
#      - Server Management
#      - Printer / Scanner
#      - NetArch 9
#      - Physical Server - Linux
#      - Connectivity issue
#      - Storage
#      - Asset Allocation Issues
#      - Azure/Aws/GCP ticket creation
#      - Port
#      - VPN
#      - CRM
#      - Other Accessories
#      - Service down
#      - File Transfer
#      - RMG Portal
#      - Agent
#      - Others
#      - Time & Billing
#      - Password Reset
#      - e-Voice
#      - EPayroll
#      - Switch / Router
#      - Data
#      - Scanner
#      - Alerts Monitoring
#      - Performance Issue
#      - Server or Cloud Alerts
#      - CUIC
#      - Other Software
#      - Error
#      - User name / Email ID changes for existing
#      - People Soft Finance
#      - Software
#      - InactiveTerminalSessions
#      - Slow
#      - Other
#      - Laptop
#      - NIC (Network Interface Card)
#      - MyBenefits
#      - Anti Virus
#      - IT Proof
#      - VC room
#      - CPU Utilization
#      - Virtual Server - Windows
#      - Service Operations
#      - Kramer Room scheduler not working
#      - Virus Infection
#      - Mouse
#      - Login Issues
#      - WiFi
#      - Down
#      - ART
#      - Database
#      - Application
#      - Firmware
#      - Operating System
#      - Audio issue
#      - Video Conference
#      - PeopleSoft HRMS
#      - End user computing (Deskside) services
#      - Expense Claim System
#      - Audio Quality issues in WebEx Meeting
#      - Outbound Call
#      - Citrix
#      - Vendor Payment System
#      - Patch Management
#      - Webex Login Issue
#      - Finesse
#      - Memory Utilization
#      - Clearance Process
#      - Revenue Tracker
#      - Firewall
#      - Clouds VM maintenance
#      - DAT update
#      - Customer Delight
#      - Links
#      - AskGenie Administration
#      - SVN
#      - DID Mapping
#      - Hunt Group Call Landing
#      - Windows Updates
#      - Compass
#      - ION
#      - Physical Server - Windows
#      - Stationh Admin
#      - Other Applications
#      - Allowances
#      - Internet Connectivity
#      - Global Protect VPN
#      - Mobile App
#      - Diskspace Utilization
#      - Disk Clean Up
#      - Performance
#    - **Mandatory:** Yes
#
# 7. **Category:** This field captures the broader category under which the service falls.
#    - **Type:** Reference
#    - **Reference:** `u_service`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Reference Qualifier:** `javascript:new ShowCatagory().catagory()`
#    - **Choices:** [Same as Service choices]
#    - **Mandatory:** Yes
#
# 8. **Child Category 1:** This field captures a more specific sub-category related to the service.
#    - **Type:** Reference
#    - **Reference:** `u_service`
#    - **Attributes:** `edge_encryption_enabled=true,ref_qual_elements=category`
#    - **Reference Qualifier:** `javascript:new ShowCatagory().childCatagory()`
#    - **Choices:** [Same as Service choices]
#    - **Mandatory:** Yes
#
# 9. **Short Description:** This field captures a brief summary of the incident.
#    - **Type:** Single Line Text
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Mandatory:** Yes
#
# 10. **Detailed Description:** This field captures a detailed description of the incident.
#     - **Type:** Single Line Text
#     - **Attributes:** `edge_encryption_enabled=true`
#     - **Mandatory:** Yes
#
# 11. **Add Attachment:** This field allows users to add attachments related to the incident.
#     - **Type:** Attachment
#     - **Attributes:** `edge_encryption_enabled=true`
#     - **Max File Size:** 20 MB
#     - **Mandatory:** No

# %%
docs = db2.similarity_search_with_relevance_scores(query)
print(docs)
# Out:
# Number of requested results 4 is greater than number of elements in index 1, updating n_results = 1
# [(Document(metadata={'short_description': 'Get support with STG issues that you are facing', 'sys_id': '39dbfcc3c3489a1068d8b132b4013167', 'sys_name': 'Report IT Incidents'}, page_content='**Catalog Item Name:** Report IT Incidents\n\n**Description:** This catalog item allows users to report IT incidents they are experiencing and seek assistance for specific issues. The submission form gathers essential details to ensure the incident is accurately logged and addressed promptly.\n\n**Variables (Fields):**\n\n1. **Reported For:** This field captures the user for whom the incident is being reported. \n   - **Type:** Requested For\n   - **Reference:** `sys_user`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n   - **Dynamic Value:** `javascript:gs.getUserID();`\n\n2. **Location:** This field captures the location of the user reporting the incident. \n   - **Type:** Reference\n   - **Reference:** `cmn_location`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Dynamic Value Field:** `reported_for`\n   - **Dynamic Value Dot Walk Path:** `location`\n   - **Mandatory:** Yes\n\n3. **Contact Number:** This field captures the contact number of the user reporting the incident.\n   - **Type:** Single Line Text\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n\n4. **Project:** This field captures the project or department associated with the incident.\n   - **Type:** Reference\n   - **Reference:** `cmn_department`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Dynamic Value Field:** `reported_for`\n   - **Dynamic Value Dot Walk Path:** `department`\n   - **Mandatory:** Yes\n\n5. **Building:** This field captures the building name or number where the incident occurred.\n   - **Type:** Single Line Text\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n\n6. **Service:** This field captures the specific service related to the incident.\n   - **Type:** Reference\n   - **Reference:** `u_service`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Reference Qualifier:** `u_parent_fieldISEMPTY^EQ`\n   - **Choices:** \n     - Access Related issue\n     - Visa Requisition\n     - Microsoft Office\n     - Voice Instance\n     - Call Flow\n     - Account Unlock\n     - Inbound Call\n     - Skype / Teams\n     - Desktop\n     - Computer Accessories\n     - Hardware\n     - IIS Operations Support\n     - Virtualization\n     - DC Ops Services\n     - Access\n     - Touch panal issue\n     - Plan Arena\n     - Video Conferencing\n     - Recording\n     - Network Services\n     - SPAM Email\n     - Switch\n     - Router\n     - Email\n     - Verint\n     - Attendance Tracker\n     - SLAs\n     - Email Services\n     - Data Card\n     - Memory\n     - Application Issue\n     - Wireless Controller\n     - Unable to find Recordings or Deleted rec\n     - CPPM\n     - Mail Delivery Issue\n     - SFTP (Secure File Transfer Protocol)\n     - Microphone issue\n     - Peripheral Devices\n     - IVR (Interactive Voice Response)\n     - Reports\n     - Nice\n     - Voice Services\n     - Slowness issue\n     - Service Request\n     - Voice Quality\n     - Break - Fix\n     - IP Phone\n     - CPU\n     - Active Sync\n     - Content sharing issue\n     - VPN Related Issues\n     - Keyboard\n     - Browser\n     - Availability\n     - Module\n     - Camera issue\n     - Application or Database Alerts\n     - Hex_EY VPN Related Issues\n     - Virtual Server - Linux\n     - MS Outlook\n     - Full and Final Settlement\n     - Antivirus Updates\n     - Cloud Ops\n     - Network alerts\n     - Printer\n     - AskGenie\n     - MY HR\n     - User Account Management\n     - Reporting\n     - Application Services\n     - Agent Login\n     - User account disable - Batch job failure\n     - Webex\n     - Board Room\n     - Backup / Restore\n     - Mobile Device\n     - Server Management\n     - Printer / Scanner\n     - NetArch 9\n     - Physical Server - L ...
# c:\Users\2000081253\Desktop\Work\AI-Copilot-Ticket-Assistant\.venv\Lib\site-packages\langchain_core\vectorstores\base.py:784: UserWarning: Relevance scores must be between 0 and 1, got [(Document(metadata={'short_description': 'Get support with STG issues that you are facing', 'sys_id': '39dbfcc3c3489a1068d8b132b4013167', 'sys_name': 'Report IT Incidents'}, page_content='**Catalog Item Name:** Report IT Incidents\n\n**Description:** This catalog item allows users to report IT incidents they are experiencing and seek assistance for specific issues. The submission form gathers essential details to ensure the incident is accurately logged and addressed promptly.\n\n**Variables (Fields):**\n\n1. **Reported For:** This field captures the user for whom the incident is being reported. \n   - **Type:** Requested For\n   - **Reference:** `sys_user`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n   - **Dynamic Value:** `javascript:gs.getUserID();`\n\n2. **Location:** This field captures the location of the user reporting the incident. \n   - **Type:** Reference\n   - **Reference:** `cmn_location`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Dynamic Value Field:** `reported_for`\n   - **Dynamic Value Dot Walk Path:** `location`\n   - **Mandatory:** Yes\n\n3. **Contact Number:** This field captures the contact number of the user reporting the incident.\n   - **Type:** Single Line Text\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n\n4. **Project:** This field captures the project or department associated with the incident.\n   - **Type:** Reference\n   - **Reference:** `cmn_department`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Dynamic Value Field:** `reported_for`\n   - **Dynamic Value Dot Walk Path:** `department`\n   - **Mandatory:** Yes\n\n5. **Building:** This field captures the building name or number where the incident occurred.\n   - **Type:** Single Line Text\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n\n6. **Service:** This field captures the specific service related to the incident.\n   - **Type:** Reference\n   - **Reference:** `u_service`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Reference Qualifier:** `u_parent_fieldISEMPTY^EQ`\n   - **Choices:** \n     - Access Related issue\n     - Visa Requisition\n     - Microsoft Office\n     - Voice Instance\n     - Call Flow\n     - Account Unlock\n     - Inbound Call\n     - Skype / Teams\n     - Desktop\n     - Computer Accessories\n     - Hardware\n     - IIS Operations Support\n     - Virtualization\n     - DC Ops Services\n     - Access\n     - Touch panal issue\n     - Plan Arena\n     - Video Conferencing\n     - Recording\n     - Network Services\n     - SPAM Email\n     - Switch\n     - Router\n     - Email\n     - Verint\n     - Attendance Tracker\n     - SLAs\n     - Email Services\n     - Data Card\n     - Memory\n     - Application Issue\n     - Wireless Controller\n     - Unable to find Recordings or Deleted rec\n     - CPPM\n     - Mail Delivery Issue\n     - SFTP (Secure File Transfer Protocol)\n     - Microphone issue\n     - Peripheral Devices\n     - IVR (Interactive Voice Response)\n     - Reports\n     - Nice\n     - Voice Services\n     - Slowness issue\n     - Service Request\n     - Voice Quality\n     - Break - Fix\n     - IP Phone\n     - CPU\n     - Active Sync\n     - Content sharing issue\n     - VPN Related Issues\n     - Keyboard\n     - Browser\n     - Availability\n     - Module\n     - Camera issue\n     - Application or Database Alerts\n     - Hex_EY VPN Related Issues\n     - Virtual Server - Linux\n     - MS Outlook\n     - Full and Final Settlement\n     - Antivirus Updates\n     - Cloud Ops\n     - Network alerts\n     - Printer\n     - AskGenie\n     - MY HR\n     - User Account Management\n     - Reporting\n     - Application Services\n     - Agent Login\n     - User account disable - Batch job  ...
#   warnings.warn(

# %%
print(docs[0][0].page_content)
# Out:
# **Catalog Item Name:** Report IT Incidents
#
# **Description:** This catalog item allows users to report IT incidents they are experiencing and seek assistance for specific issues. The submission form gathers essential details to ensure the incident is accurately logged and addressed promptly.
#
# **Variables (Fields):**
#
# 1. **Reported For:** This field captures the user for whom the incident is being reported.
#    - **Type:** Requested For
#    - **Reference:** `sys_user`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Mandatory:** Yes
#    - **Dynamic Value:** `javascript:gs.getUserID();`
#
# 2. **Location:** This field captures the location of the user reporting the incident.
#    - **Type:** Reference
#    - **Reference:** `cmn_location`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Dynamic Value Field:** `reported_for`
#    - **Dynamic Value Dot Walk Path:** `location`
#    - **Mandatory:** Yes
#
# 3. **Contact Number:** This field captures the contact number of the user reporting the incident.
#    - **Type:** Single Line Text
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Mandatory:** Yes
#
# 4. **Project:** This field captures the project or department associated with the incident.
#    - **Type:** Reference
#    - **Reference:** `cmn_department`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Dynamic Value Field:** `reported_for`
#    - **Dynamic Value Dot Walk Path:** `department`
#    - **Mandatory:** Yes
#
# 5. **Building:** This field captures the building name or number where the incident occurred.
#    - **Type:** Single Line Text
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Mandatory:** Yes
#
# 6. **Service:** This field captures the specific service related to the incident.
#    - **Type:** Reference
#    - **Reference:** `u_service`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Reference Qualifier:** `u_parent_fieldISEMPTY^EQ`
#    - **Choices:**
#      - Access Related issue
#      - Visa Requisition
#      - Microsoft Office
#      - Voice Instance
#      - Call Flow
#      - Account Unlock
#      - Inbound Call
#      - Skype / Teams
#      - Desktop
#      - Computer Accessories
#      - Hardware
#      - IIS Operations Support
#      - Virtualization
#      - DC Ops Services
#      - Access
#      - Touch panal issue
#      - Plan Arena
#      - Video Conferencing
#      - Recording
#      - Network Services
#      - SPAM Email
#      - Switch
#      - Router
#      - Email
#      - Verint
#      - Attendance Tracker
#      - SLAs
#      - Email Services
#      - Data Card
#      - Memory
#      - Application Issue
#      - Wireless Controller
#      - Unable to find Recordings or Deleted rec
#      - CPPM
#      - Mail Delivery Issue
#      - SFTP (Secure File Transfer Protocol)
#      - Microphone issue
#      - Peripheral Devices
#      - IVR (Interactive Voice Response)
#      - Reports
#      - Nice
#      - Voice Services
#      - Slowness issue
#      - Service Request
#      - Voice Quality
#      - Break - Fix
#      - IP Phone
#      - CPU
#      - Active Sync
#      - Content sharing issue
#      - VPN Related Issues
#      - Keyboard
#      - Browser
#      - Availability
#      - Module
#      - Camera issue
#      - Application or Database Alerts
#      - Hex_EY VPN Related Issues
#      - Virtual Server - Linux
#      - MS Outlook
#      - Full and Final Settlement
#      - Antivirus Updates
#      - Cloud Ops
#      - Network alerts
#      - Printer
#      - AskGenie
#      - MY HR
#      - User Account Management
#      - Reporting
#      - Application Services
#      - Agent Login
#      - User account disable - Batch job failure
#      - Webex
#      - Board Room
#      - Backup / Restore
#      - Mobile Device
#      - Server Management
#      - Printer / Scanner
#      - NetArch 9
#      - Physical Server - Linux
#      - Connectivity issue
#      - Storage
#      - Asset Allocation Issues
#      - Azure/Aws/GCP ticket creation
#      - Port
#      - VPN
#      - CRM
#      - Other Accessories
#      - Service down
#      - File Transfer
#      - RMG Portal
#      - Agent
#      - Others
#      - Time & Billing
#      - Password Reset
#      - e-Voice
#      - EPayroll
#      - Switch / Router
#      - Data
#      - Scanner
#      - Alerts Monitoring
#      - Performance Issue
#      - Server or Cloud Alerts
#      - CUIC
#      - Other Software
#      - Error
#      - User name / Email ID changes for existing
#      - People Soft Finance
#      - Software
#      - InactiveTerminalSessions
#      - Slow
#      - Other
#      - Laptop
#      - NIC (Network Interface Card)
#      - MyBenefits
#      - Anti Virus
#      - IT Proof
#      - VC room
#      - CPU Utilization
#      - Virtual Server - Windows
#      - Service Operations
#      - Kramer Room scheduler not working
#      - Virus Infection
#      - Mouse
#      - Login Issues
#      - WiFi
#      - Down
#      - ART
#      - Database
#      - Application
#      - Firmware
#      - Operating System
#      - Audio issue
#      - Video Conference
#      - PeopleSoft HRMS
#      - End user computing (Deskside) services
#      - Expense Claim System
#      - Audio Quality issues in WebEx Meeting
#      - Outbound Call
#      - Citrix
#      - Vendor Payment System
#      - Patch Management
#      - Webex Login Issue
#      - Finesse
#      - Memory Utilization
#      - Clearance Process
#      - Revenue Tracker
#      - Firewall
#      - Clouds VM maintenance
#      - DAT update
#      - Customer Delight
#      - Links
#      - AskGenie Administration
#      - SVN
#      - DID Mapping
#      - Hunt Group Call Landing
#      - Windows Updates
#      - Compass
#      - ION
#      - Physical Server - Windows
#      - Stationh Admin
#      - Other Applications
#      - Allowances
#      - Internet Connectivity
#      - Global Protect VPN
#      - Mobile App
#      - Diskspace Utilization
#      - Disk Clean Up
#      - Performance
#    - **Mandatory:** Yes
#
# 7. **Category:** This field captures the broader category under which the service falls.
#    - **Type:** Reference
#    - **Reference:** `u_service`
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Reference Qualifier:** `javascript:new ShowCatagory().catagory()`
#    - **Choices:** [Same as Service choices]
#    - **Mandatory:** Yes
#
# 8. **Child Category 1:** This field captures a more specific sub-category related to the service.
#    - **Type:** Reference
#    - **Reference:** `u_service`
#    - **Attributes:** `edge_encryption_enabled=true,ref_qual_elements=category`
#    - **Reference Qualifier:** `javascript:new ShowCatagory().childCatagory()`
#    - **Choices:** [Same as Service choices]
#    - **Mandatory:** Yes
#
# 9. **Short Description:** This field captures a brief summary of the incident.
#    - **Type:** Single Line Text
#    - **Attributes:** `edge_encryption_enabled=true`
#    - **Mandatory:** Yes
#
# 10. **Detailed Description:** This field captures a detailed description of the incident.
#     - **Type:** Single Line Text
#     - **Attributes:** `edge_encryption_enabled=true`
#     - **Mandatory:** Yes
#
# 11. **Add Attachment:** This field allows users to add attachments related to the incident.
#     - **Type:** Attachment
#     - **Attributes:** `edge_encryption_enabled=true`
#     - **Max File Size:** 20 MB
#     - **Mandatory:** No

# %%
docs
# Out:
# [(Document(metadata={'short_description': 'Get support with STG issues that you are facing', 'sys_id': '39dbfcc3c3489a1068d8b132b4013167', 'sys_name': 'Report IT Incidents'}, page_content='**Catalog Item Name:** Report IT Incidents\n\n**Description:** This catalog item allows users to report IT incidents they are experiencing and seek assistance for specific issues. The submission form gathers essential details to ensure the incident is accurately logged and addressed promptly.\n\n**Variables (Fields):**\n\n1. **Reported For:** This field captures the user for whom the incident is being reported. \n   - **Type:** Requested For\n   - **Reference:** `sys_user`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n   - **Dynamic Value:** `javascript:gs.getUserID();`\n\n2. **Location:** This field captures the location of the user reporting the incident. \n   - **Type:** Reference\n   - **Reference:** `cmn_location`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Dynamic Value Field:** `reported_for`\n   - **Dynamic Value Dot Walk Path:** `location`\n   - **Mandatory:** Yes\n\n3. **Contact Number:** This field captures the contact number of the user reporting the incident.\n   - **Type:** Single Line Text\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n\n4. **Project:** This field captures the project or department associated with the incident.\n   - **Type:** Reference\n   - **Reference:** `cmn_department`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Dynamic Value Field:** `reported_for`\n   - **Dynamic Value Dot Walk Path:** `department`\n   - **Mandatory:** Yes\n\n5. **Building:** This field captures the building name or number where the incident occurred.\n   - **Type:** Single Line Text\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n\n6. **Service:** This field captures the specific service related to the incident.\n   - **Type:** Reference\n   - **Reference:** `u_service`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Reference Qualifier:** `u_parent_fieldISEMPTY^EQ`\n   - **Choices:** \n     - Access Related issue\n     - Visa Requisition\n     - Microsoft Office\n     - Voice Instance\n     - Call Flow\n     - Account Unlock\n     - Inbound Call\n     - Skype / Teams\n     - Desktop\n     - Computer Accessories\n     - Hardware\n     - IIS Operations Support\n     - Virtualization\n     - DC Ops Services\n     - Access\n     - Touch panal issue\n     - Plan Arena\n     - Video Conferencing\n     - Recording\n     - Network Services\n     - SPAM Email\n     - Switch\n     - Router\n     - Email\n     - Verint\n     - Attendance Tracker\n     - SLAs\n     - Email Services\n     - Data Card\n     - Memory\n     - Application Issue\n     - Wireless Controller\n     - Unable to find Recordings or Deleted rec\n     - CPPM\n     - Mail Delivery Issue\n     - SFTP (Secure File Transfer Protocol)\n     - Microphone issue\n     - Peripheral Devices\n     - IVR (Interactive Voice Response)\n     - Reports\n     - Nice\n     - Voice Services\n     - Slowness issue\n     - Service Request\n     - Voice Quality\n     - Break - Fix\n     - IP Phone\n     - CPU\n     - Active Sync\n     - Content sharing issue\n     - VPN Related Issues\n     - Keyboard\n     - Browser\n     - Availability\n     - Module\n     - Camera issue\n     - Application or Database Alerts\n     - Hex_EY VPN Related Issues\n     - Virtual Server - Linux\n     - MS Outlook\n     - Full and Final Settlement\n     - Antivirus Updates\n     - Cloud Ops\n     - Network alerts\n     - Printer\n     - AskGenie\n     - MY HR\n     - User Account Management\n     - Reporting\n     - Application Services\n     - Agent Login\n     - User account disable - Batch job failure\n     - Webex\n     - Board Room\n     - Backup / Restore\n     - Mobile Device\n     - Server Management\n     - Printer / Scanner\n     - NetArch 9\n     - Physical Server - L ...
#   -0.3483407386757016)]

# %%
# load from disk
# db3 = Chroma(persist_directory="./chroma_db", embedding_function=embedding_function)
# docs = db3.similarity_search(query)
# print(docs[0].page_content)

# %%
docs
# Out:
# [(Document(metadata={'short_description': 'Get support with STG issues that you are facing', 'sys_id': '39dbfcc3c3489a1068d8b132b4013167', 'sys_name': 'Report IT Incidents'}, page_content='**Catalog Item Name:** Report IT Incidents\n\n**Description:** This catalog item allows users to report IT incidents they are experiencing and seek assistance for specific issues. The submission form gathers essential details to ensure the incident is accurately logged and addressed promptly.\n\n**Variables (Fields):**\n\n1. **Reported For:** This field captures the user for whom the incident is being reported. \n   - **Type:** Requested For\n   - **Reference:** `sys_user`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n   - **Dynamic Value:** `javascript:gs.getUserID();`\n\n2. **Location:** This field captures the location of the user reporting the incident. \n   - **Type:** Reference\n   - **Reference:** `cmn_location`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Dynamic Value Field:** `reported_for`\n   - **Dynamic Value Dot Walk Path:** `location`\n   - **Mandatory:** Yes\n\n3. **Contact Number:** This field captures the contact number of the user reporting the incident.\n   - **Type:** Single Line Text\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n\n4. **Project:** This field captures the project or department associated with the incident.\n   - **Type:** Reference\n   - **Reference:** `cmn_department`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Dynamic Value Field:** `reported_for`\n   - **Dynamic Value Dot Walk Path:** `department`\n   - **Mandatory:** Yes\n\n5. **Building:** This field captures the building name or number where the incident occurred.\n   - **Type:** Single Line Text\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Mandatory:** Yes\n\n6. **Service:** This field captures the specific service related to the incident.\n   - **Type:** Reference\n   - **Reference:** `u_service`\n   - **Attributes:** `edge_encryption_enabled=true`\n   - **Reference Qualifier:** `u_parent_fieldISEMPTY^EQ`\n   - **Choices:** \n     - Access Related issue\n     - Visa Requisition\n     - Microsoft Office\n     - Voice Instance\n     - Call Flow\n     - Account Unlock\n     - Inbound Call\n     - Skype / Teams\n     - Desktop\n     - Computer Accessories\n     - Hardware\n     - IIS Operations Support\n     - Virtualization\n     - DC Ops Services\n     - Access\n     - Touch panal issue\n     - Plan Arena\n     - Video Conferencing\n     - Recording\n     - Network Services\n     - SPAM Email\n     - Switch\n     - Router\n     - Email\n     - Verint\n     - Attendance Tracker\n     - SLAs\n     - Email Services\n     - Data Card\n     - Memory\n     - Application Issue\n     - Wireless Controller\n     - Unable to find Recordings or Deleted rec\n     - CPPM\n     - Mail Delivery Issue\n     - SFTP (Secure File Transfer Protocol)\n     - Microphone issue\n     - Peripheral Devices\n     - IVR (Interactive Voice Response)\n     - Reports\n     - Nice\n     - Voice Services\n     - Slowness issue\n     - Service Request\n     - Voice Quality\n     - Break - Fix\n     - IP Phone\n     - CPU\n     - Active Sync\n     - Content sharing issue\n     - VPN Related Issues\n     - Keyboard\n     - Browser\n     - Availability\n     - Module\n     - Camera issue\n     - Application or Database Alerts\n     - Hex_EY VPN Related Issues\n     - Virtual Server - Linux\n     - MS Outlook\n     - Full and Final Settlement\n     - Antivirus Updates\n     - Cloud Ops\n     - Network alerts\n     - Printer\n     - AskGenie\n     - MY HR\n     - User Account Management\n     - Reporting\n     - Application Services\n     - Agent Login\n     - User account disable - Batch job failure\n     - Webex\n     - Board Room\n     - Backup / Restore\n     - Mobile Device\n     - Server Management\n     - Printer / Scanner\n     - NetArch 9\n     - Physical Server - L ...
#   -0.3483407386757016)]

# %%
def fetchDescribe(data):

    template = """{data}
    
    from the given data Return only the 100 words of description of the catalog item.
    Output should not contain the variables
    And no premable or explaination.

    """
    
    prompt_template = PromptTemplate(template=template, input_variables=["data"])
    chain = prompt_template | model | StrOutputParser()
    response = chain.invoke({"data": data})
    return response

# %%
def fetchVariables(data, variables_name):

    template = """{data}
    
    from the given data Return only the variables name as a key and variable description as a value in JSON.
    The description must describe contains choices and ui_policy too as a single output
    The variablename should be one of the name from the given List. {variables_name}
    And no premable or explaination.

    Example:
    variablename : variabledescription

    """
    
    prompt_template = PromptTemplate(template=template, input_variables=["data", "variables_name"])
    chain = prompt_template | model | JsonOutputParser()
    response = chain.invoke({"data": data, "variables_name": variables_name})
    return response

# %%
variables = fetchVariables(docs[0][0].page_content, variables_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 variables = fetchVariables(docs[0][0].page_content, variables_name)
#
# NameError: name 'variables_name' is not defined

# %%
variables
# Out:
# {'requested_for': "This is a mandatory field to specify the user for whom the request is being made. The default value is set to the current user (System Administrator). UI Policy: If the selected 'Business Service' is 'Software Installation', this field becomes mandatory.",
#  'contact_number': 'This is a mandatory single-line text field for entering the contact number of the requester.',
#  'Location': "This is an optional reference field to specify the location. The value is dynamically fetched based on the 'Requested For' field.",
#  'project_name': "This is an optional reference field to specify the project name. The value is dynamically fetched based on the 'Requested For' field.",
#  'business_service': "This is a mandatory reference field to select the business service. Choices: OS Upgrade, Software Installation, Software Uninstallation. UI Policy: If the selected value is 'Software Installation' or 'Software Uninstallation', additional fields become mandatory and visible.",
#  'software_name': 'This is an optional reference field to specify the software name. Choices: Google Meet, GameMaker Studio, Mathematica, Stata, PowerShell, Ada, SAS, Haskell, Blender, Grammarly, 3ds Max, Objective-C, R, Scrivener, PHP, Redis, Google Chrome, TensorFlow, Mozilla Firefox, Bitbucket, CSS, Sketch, CorelDRAW, Adobe Photoshop, HTML, Slack SDK, Minitab, Sass, NetBeans, Lua, Shell Scripting (Bash), Mendeley, Trello, PyCharm, Kotlin SDK, RStudio, Amplitude SDK, COBOL, Sublime Text, F#, Microsoft SQL Server, C#, PyTorch, Qt SDK, Adobe Illustrator, Julia, Zoom SDK, Hadoop, React Native SDK, Stripe SDK, ARKit, LaTeX, GTK+ SDK, D, Crystal, PostgreSQL, Slack, Microsoft Word, NVivo, Zoom, QuickBooks, Microsoft Edge, Box SDK, MATLAB, Firebase SDK, Java, Vagrant, SAP, Rust, Sage 50, Google Cloud SDK, Xamarin SDK, Clojure, Spring Framework, VHDL, SPSS, Apache Spark, SolidWorks, Pascal, VB.NET, Scikit-learn, Discord SDK, Microsoft PowerPoint, EndNote, Terraform, Xcode, Affinity Photo, InVision, Figma, Twitter SDK, Tcl, Power BI, Prolog, iOS SDK, Unreal Engine, IntelliJ IDEA, Perl, NoSQL, Xero, Node.js SDK, Azure SDK, TensorFlow SDK, FreshBooks, Celtx, Java Development Kit (JDK), Ansible, Adobe Acrobat Reader, Maya, Twilio SDK, Nim, Canva, OpenCV SDK, Atom, Mixpanel SDK, Procreate, Facebook SDK, C, Jenkins, AWS SDK, RPG Maker, Salesforce, SQLite, SQL, Swift SDK, Keras, Jupyter Notebook, Elixir, New Relic SDK, Telegram Bot SDK, Apache Cordova SDK, Cocoa Touch, QlikView, Electron SDK, Go (Golang), Adobe Premiere Pro, Unreal Engine SDK, MongoDB, Swift, Segment SDK, OneSignal SDK, Realm SDK, Ruby, PayPal SDK, Intercom SDK, Verilog, Adobe After Effects, Eclipse, Google Maps SDK, Common Lisp, Unity, Android SDK, Skype, Oracle Database, Dropbox SDK, Overleaf, Kubernetes, Erlang, JavaScript, Flutter SDK, Opera, .NET SDK, SAP SDK, GitLab, Sentry SDK, Notepad++, Salesforce SDK, Android Studio, SketchUp, Cassandra, Assembly Language, Zotero, Jira, TypeScript, AutoCAD, Kotlin, C++, MySQL, Dart, ARCore, Safari, Agora SDK, Scala, Asana, Visual Studio Code, Affinity Designer, Final Draft, Microsoft Excel, Tableau, Fortran, Docker, Unity SDK, Groovy, Less, Windows SDK, GitHub, Python, Scheme, Microsoft Teams.',
#  'add_software': 'This is an optional checkbox to indicate if additional software needs to be added. UI Policy: If checked, additional fields (Software Name 1, Request Type 1, and Duration 1) become mandatory and visible.',
#  'request_type': "This is an optional single-line text field to specify the type of request. UI Policy: If the 'Business Service' is 'Software Installation', this field becomes mandatory.",
#  'duration': "This is an optional select box to specify the duration. Choices: None, 30 days, 60 days, 90 days, 180 days, 360 days. UI Policy: If the 'Business Service' is 'Software Installation', this field becomes mandatory.",
#  'software_name1': "This is an optional reference field to specify the additional software name. Choices: Same as 'Software Name'. UI Policy: If the 'Add Software' checkbox is checked, this field becomes mandatory.",
#  'add_software1': 'This is an optional checkbox to indicate if another additional software needs to be added. UI Policy: If checked, additional fields (Software Name 2, Request Type 2, and Duration 2) become mandatory and visible.',
#  'request_type1': "This is an optional single-line text field to specify the type of request for the additional software. UI Policy: If the 'Add Software' checkbox is checked, this field becomes mandatory.",
#  'duration1': "This is an optional select box to specify the duration for the additional software. Choices: Same as 'Duration'. UI Policy: If the 'Add Software' checkbox is checked, this field becomes mandatory.",
#  'software_name2': "This is an optional reference field to specify another additional software name. Choices: Same as 'Software Name'. UI Policy: If the 'Add Software 1' checkbox is checked, this field becomes mandatory.",
#  'add_software2': 'This is an optional checkbox to indicate if yet another additional software needs to be added. UI Policy: If checked, additional fields (Software Name 3, Request Type 3, and Duration 3) become mandatory and visible.',
#  'request_type2': "This is an optional single-line text field to specify the type of request for the another additional software. UI Policy: If the 'Add Software 1' checkbox is checked, this field becomes mandatory.",
#  'duration2': "This is an optional select box to specify the duration for the another additional software. Choices: Same as 'Duration'. UI Policy: If the 'Add Software 1' checkbox is checked, this field becomes mandatory.",
#  'software_name3': "This is an optional reference field to specify yet another additional software name. Choices: Same as 'Software Name'. UI Policy: If the 'Business Service' is 'Software Uninstallation', this field becomes mandatory.",
#  'select_your_host_name': 'This is a mandatory lookup select box to specify the host name. Choices: HostName1, HostName2, HostName3.'}

# %%
CATALOGITEMDOCS = "Document_Store\\catalog_item_db"
dir_path = os.path.join(os.getcwd(), CATALOGITEMDOCS)
isdir = os.path.isdir(dir_path)

# %%
dir_path
# Out:
# 'c:\\Users\\2000081253\\Desktop\\Work\\AI-Copilot-Ticket-Assistant\\src\\Draft-Folder\\Document_Store\\catalog_item_db'

# %%
import sqlite3
import os

db_path = "c:\\Users\\2000081253\\Desktop\\Work\\AI-Copilot-Ticket-Assistant\\src\\Document_Store\\catalog_item_db\\chroma.sqlite3"

row_id = 0
catalog_item_description = ""
conn = sqlite3.connect(db_path)
cursor = conn.cursor()
cursor.execute("SELECT * FROM embedding_metadata") 
rows = cursor.fetchall()
for row in rows:
    if(row[1] == 'sys_id' and row[2] == '50572ffac3405a1068d8b132b4013177'):    
        row_id = row[0]
for row in rows:
    if(row[0] == row_id and row[1] == 'chroma:document'):
        catalog_item_description = row[2]
conn.close()
print(catalog_item_description)
# Out:
# Catalog Item Name: Software Services
#
# Description: This catalog item allows users to request various software services, including OS upgrades, software installation, and uninstallation. Please select the appropriate business function/request type to display the delivery time. This service is available on desktop, and you can add multiple software items if required.
#
# Variables (Fields):
#
# 1. Requested For: This is a mandatory field that specifies the user for whom the software service is requested. The default value is set to "System Administrator."
#
# 2. Contact Number: This is a mandatory field where you need to enter your contact number to facilitate communication.
#
# 3. Location: This field is not mandatory and allows you to specify the location related to the request. The location will be dynamically fetched based on the "Requested For" field.
#
# 4. Project Name: This field is not mandatory and allows you to specify the project associated with the request. The project name will be dynamically fetched based on the "Requested For" field.
#
# 5. Business Service: This is a mandatory field where you need to select the type of business service required. The available choices are:
#    - OS Upgrade
#    - Software Installation
#    - Software Uninstallation
#
#    UI Policy:
#    - If the business service is "Software Installation," the following fields become mandatory and visible:
#      - Request Type
#      - Software Name
#      - Duration
#      - Add Software (visible but not mandatory)
#
# 6. Software Name: This field is not mandatory and allows you to specify the software required. The available choices include:
#    - PowerShell
#    - Swift
#    - COBOL
#    - Minitab
#    - Verilog
#    - Flutter SDK
#    - Xcode
#    - Overleaf
#    - Microsoft PowerPoint
#    - Node.js SDK
#    - Erlang
#    - Power BI
#    - InVision
#    - Apache Cordova SDK
#    - Common Lisp
#    - RStudio
#    - JavaScript
#    - Google Chrome
#    - Dart
#    - AutoCAD
#    - QlikView
#    - Scala
#    - Julia
#    - Perl
#    - R
#    - Prolog
#    - Box SDK
#    - HTML
#    - Celtx
#    - Microsoft Word
#    - Scikit-learn
#    - Haskell
#    - .NET SDK
#    - SolidWorks
#    - IntelliJ IDEA
#    - Slack
#    - React Native SDK
#    - PyCharm
#    - Jenkins
#    - CSS
#    - Go (Golang)
#    - PayPal SDK
#    - QuickBooks
#    - iOS SDK
#    - Facebook SDK
#    - TensorFlow SDK
#    - SQLite
#    - Docker
#    - Apache Spark
#    - Groovy
#    - Grammarly
#    - Azure SDK
#    - Notepad++
#    - Java Development Kit (JDK)
#    - TypeScript
#    - Sketch
#    - Dropbox SDK
#    - Spring Framework
#    - Google Maps SDK
#    - Elixir
#    - NVivo
#    - Sublime Text
#    - Adobe Photoshop
#    - VHDL
#    - MongoDB
#    - Adobe After Effects
#    - Assembly Language
#    - Mixpanel SDK
#    - Unreal Engine SDK
#    - PHP
#    - Stata
#    - CorelDRAW
#    - GitLab
#    - D
#    - Sass
#    - Bitbucket
#    - AWS SDK
#    - Visual Studio Code
#    - Xero
#    - SAP
#    - RPG Maker
#    - MATLAB
#    - OpenCV SDK
#    - Affinity Photo
#    - Crystal
#    - Firebase SDK
#    - Rust
#    - Java
#    - Opera
#    - Zotero
#    - 3ds Max
#    - C++
#    - Kubernetes
#    - Figma
#    - Asana
#    - Shell Scripting (Bash)
#    - Google Cloud SDK
#    - LaTeX
#    - Trello
#    - EndNote
#    - Slack SDK
#    - Android Studio
#    - C#
#    - SketchUp
#    - PostgreSQL
#    - Pascal
#    - ARKit
#    - Fortran
#    - Microsoft Teams
#    - SAS
#    - SAP SDK
#    - Amplitude SDK
#    - Salesforce SDK
#    - VB.NET
#    - Telegram Bot SDK
#    - Lua
#    - Less
#    - Zoom
#    - Nim
#    - Android SDK
#    - Adobe Premiere Pro
#    - Vagrant
#    - Unity
#    - OneSignal SDK
#    - Eclipse
#    - Qt SDK
#    - Hadoop
#    - Kotlin SDK
#    - Mendeley
#    - Scrivener
#    - NoSQL
#    - Keras
#    - C
#    - Mozilla Firefox
#    - Procreate
#    - SPSS
#    - Tcl
#    - Adobe Illustrator
#    - Oracle Database
#    - Scheme
#    - ARCore
#    - Stripe SDK
#    - Tableau
#    - Sage 50
#    - TensorFlow
#    - Objective-C
#    - Ansible
#    - Adobe Acrobat Reader
#    - GitHub
#    - Cassandra
#    - Swift SDK
#    - Blender
#    - Unreal Engine
#    - Google Meet
#    - Microsoft Excel
#    - Zoom SDK
#    - Affinity Designer
#    - Python
#    - Ada
#    - Terraform
#    - SQL
#    - Xamarin SDK
#    - Realm SDK
#    - NetBeans
#    - GTK+ SDK
#    - Electron SDK
#    - Salesforce
#    - Unity SDK
#    - Jupyter Notebook
#    - Redis
#    - Twilio SDK
#    - Agora SDK
#    - Segment SDK
#    - Twitter SDK
#    - PyTorch
#    - Intercom SDK
#    - F#
#    - Safari
#    - Atom
#    - Sentry SDK
#    - Windows SDK
#    - Jira
#    - Skype
#    - GameMaker Studio
#    - Discord SDK
#    - Microsoft SQL Server
#    - Final Draft
#    - Clojure
#    - Cocoa Touch
#    - Mathematica
#    - Canva
#    - FreshBooks
#    - Ruby
#    - Kotlin
#    - Maya
#    - MySQL
#    - Microsoft Edge
#    - New Relic SDK
#
# 7. Add Software: This is a check box that allows you to add more software items if required. When checked, additional fields for specifying software details will become visible and mandatory.
#
#    UI Policy:
#    - If the checkbox is selected, the following fields become mandatory and visible:
#      - Software Name1
#      - Duration1
#      - Request Type1
#      - Add Software1 (visible but not mandatory)
#
# 8. Request Type: This field is not mandatory and allows you to specify the type of request for the selected software.
#
# 9. Duration: This field is not mandatory and allows you to specify the duration for which the software service is required. The available choices are:
#    - None
#    - 30 days
#    - 60 days
#    - 90 days
#    - 180 days
#    - 360 days
#
# 10. Select your Host Name: This is a mandatory lookup select box where you need to select your host name. The choices are dynamically fetched based on the "Requested For" field. The available choices include:
#     - HostName1
#     - HostName2
#     - HostName3
#
# 11. Additional Software Fields: Similar to the first software field, additional fields are provided if the "Add Software" checkbox is selected, allowing users to specify more software items, request types, and durations. The same choices and conditions apply to these fields.

# %%
print(rows)
# Out:
# [(1, 'sys_id', '0317ba9d47120510f53d37d2846d43bb', None, None, None), (1, 'sys_name', 'Request email alias', None, None, None), (1, 'short_description', 'Request for email alias', None, None, None), (1, 'chroma:document', 'Catalog Item Name: Request email alias\n\nDescription: This catalog item allows users to request a new email alias. An email alias is an alternative email address that can be used to receive emails in addition to the primary email address. This can be particularly useful for managing different roles or functions without the need for multiple email accounts. To proceed with the request, users need to provide their preferred email alias and a business justification for why the alias is needed. \n\nVariables (Fields):\n1. Preferred email alias: \n   - About the variable: This field is mandatory and requires the user to enter the preferred email alias. The alias should be unique and follow the organization’s naming conventions. Edge encryption is enabled for this field to ensure that the data is securely transmitted.\n  \n2. Business justification:\n   - About the variable: This field is mandatory and requires a detailed business justification for why the email alias is needed. The justification should explain the purpose and how it will be used to support business activities. Edge encryption is enabled for this field to ensure that the data is securely transmitted.\n\nNote: There are no specific UI policy conditions or actions associated with these variables.', None, None, None), (2, 'sys_id', '03e7c02c471e0950f53d37d2846d433c', None, None, None), (2, 'sys_name', 'Cisco jabber softphone', None, None, None), (2, 'short_description', 'Request for cisco jabber softphone', None, None, None), (2, 'chroma:document', "Catalog Item Name: Cisco Jabber Softphone\n\nDescription: \nGet secure, reliable communications with Cisco Jabber's soft-phone features, including HD voice, video, and desktop sharing. This service is available for desktop use and provides a comprehensive solution for communication needs within an organization. \n\nVariables (Fields):\n\n1. Requested for:\n   - Description: This field is used to specify the user for whom the Cisco Jabber Softphone is being requested. By default, it is set to the system administrator.\n   - Type: Requested For\n   - Mandatory: Yes\n   - Read Only: No\n   - Attributes: edge_encryption_enabled=true\n\n2. Business justification:\n   - Description: This field is used to provide a justification for why the Cisco Jabber Softphone is needed. It allows for multiple lines of text to accommodate detailed explanations.\n   - Type: Multi Line Text\n   - Mandatory: Yes\n   - Read Only: No\n   - Attributes: edge_encryption_enabled=true", None, None, None), (3, 'sys_id', '04b7e94b4f7b4200086eeed18110c7fd', None, None, None), (3, 'sys_name', 'Standard Laptop', None, None, None), (3, 'short_description', 'Lenovo - Carbon x1', None, None, None), (3, 'chroma:document', "### Catalog Item Name: Standard Laptop\n\n### Description:\nThe x1 Carbon is Lenovo's lightest ThinkPad yet. It provides a QHD display that fights glare and weighs less than three pounds, making it ideal for most computing tasks and highly mobile. \n\n**Technical Specs:**\n- Intel Core i5 processor\n- 512GB solid state drive (SSD)\n- Backlit keyboard\n\n**Price:** $1,100.00 (Annually)\n**Recurring Price:** $100.00 (Annually)\n\n### Variables (Fields):\n\n**Adobe Acrobat:**\nThis checkbox allows you to include Adobe Acrobat with your laptop. It is not mandatory and does not have any pricing implications.\n\n**Adobe Photoshop:**\nThis checkbox allows you to include Adobe Photoshop with your laptop. It is not mandatory and does not have any pricing implications.\n\n**Additional software requirements:**\nThis multi-line text field allows you to specify any additional software requirements you might have. It is not mandatory. \n\nThere are no specific UI policy conditions or actions associated with any of these variables.", None, ...

# %%
missing_variables = [{'active': True, 'label': 'Contact Number', 'dynamic_value_field': '', 'type': 6, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'single_line_text', 'display_type': 'Single Line Text', 'render_label': True, 'read_only': False, 'name': 'contact_number', 'attributes': 'edge_encryption_enabled=true', 'id': 'cfa82f7ec3405a1068d8b132b4013157', 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 2}, {'ref_qual_elements': 'requested_for', 'lookup_label': '', 'active': True, 'label': 'Select your Host Name', 'dynamic_value_field': '', 'type': 18, 'mandatory': True, 'displayvalue': '', 'friendly_type': 'lookup_select_box', 'display_type': 'Lookup Select Box', 'render_label': True, 'lookup_table': 'u_host_name', 'read_only': False, 'lookup_value': 'u_name', 'name': 'select_your_host_name', 'attributes': 'edge_encryption_enabled=true,ref_qual_elements=requested_for', 'id': 'ca5133b2c3045a1068d8b132b4013185', 'choices': [{'recurring_price_currency': '', 'price': 0.0, 'index': 0, 'recurring_price': 0.0, 'label': 'HostName1', 'value': 'HostName1', 'price_currency': ''}, {'recurring_price_currency': '', 'price': 0.0, 'index': 1, 'recurring_price': 0.0, 'label': 'HostName2', 'value': 'HostName2', 'price_currency': ''}, {'recurring_price_currency': '', 'price': 0.0, 'index': 2, 'recurring_price': 0.0, 'label': 'HostName3', 'value': 'HostName3', 'price_currency': ''}], 'value': '', 'dynamic_value_dot_walk_path': '', 'help_text': '', 'max_length': 0, 'order': 28, 'reference_values': 'HostName1, HostName2, HostName3'}, {'name': 'duration', 'mandatory': 'true'}]

# %%
fetched_variables = {'business_service': 'Software Installation',
  'software_name': 'Python',
  'add_software': 'true',
  'software_name1': 'Java',
  'add_software1': 'true',
  'software_name2': '.NET SDK',
  'requested_for': '6816f79cc0a8016401c5a33be04be441'}

missed_variables = ["duration", "select_your_host_name", "duration1", "duration2"]

# %%
def prepare_missed_param_questions(catalog_description, fetched_variables, missed_variables):

    template = """{catalog_description}
    
    I have a catalog item with the following details:

    {fetched_variables}
    
    Some variables are missing from the request:

    {missed_variables}

    Please generate a JSON object with questions for each missing variable based on the given catalog item description and fetched data. 
    The JSON should include the following missing variables: {missed_variables}. 
    Do not include choices in the questions.

    Example:
    missedvariable1: question1 etc 

    And no premable or explaination.
            

    """
    prompt_template = PromptTemplate(template=template, input_variables=["catalog_description", "fetched_variables", "missed_variables"])
    chain = prompt_template | model | JsonOutputParser()
    response = chain.invoke({"catalog_description": catalog_description, "fetched_variables": fetched_variables, "missed_variables": missed_variables})
    return response

# %%
value = prepare_missed_param_questions(catalog_item_description, fetched_variables, missed_variables)

# %%
allquestions = value
questions = [ allquestions[i] for i in allquestions]

# %%
questions
# Out:
# ['Please specify the duration for which the software service is required for Python.',
#  'Please select your host name.',
#  'Please specify the duration for which the software service is required for Java.',
#  'Please specify the duration for which the software service is required for .NET SDK.']
